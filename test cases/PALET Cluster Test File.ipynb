# %% [markdown]
# #### Cluster Test File v1.9
# Use Case: Run this file once a new version of PALET has been pushed to their respective cluster on either the PROD or VAL Servers
#
# Purpose: Does not return dataframes, this file is used to confirm that our assertations about the PALET library are correct.
#
# Functionality Testing:
#  - Paletable objects
#  - By Groups
#  - Derived By Groups
#  - Time Units
#  - Chronic Conidition
#  - Readmits*

# %%
from palet.Enrollment import Enrollment
from palet.Diagnoses import Diagnoses
from palet.ServiceCategory import ServiceCategory
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Paletable Objects - Column Check and Type Check

# %%
api = Enrollment()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %% [markdown]
# Column Check

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(type(api))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;palet.Enrollment.Enrollment&#39;&gt;
# </div>

# %% [markdown]
# Type Check

# %%
assert str(type(api)) == "<class 'palet.Enrollment.Enrollment'>", 'The Paletable object is not an Enrollment object.'
print('The Paletable object is an Enrollment object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Enrollment object.
# </div>

# %% [markdown]
# #### By Groups - Column Check and by_group Check

# %% [markdown]
# byAgeRange()

# %%
api = Enrollment().byAgeRange()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:21:29,730 - palet_log - INFO - adding byAgeRange to aggregate by Group
# 2022-05-12 14:21:29,731 - palet_log - INFO - Adding By Group age_grp_flag
# Out[8]: counter             object
# age_grp_flag        string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ageGroup            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'age_grp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'ageGroup': 'object'
}
ser = pd.Series(data=d, index=['counter','age_grp_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','ageGroup'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: counter             object
# age_grp_flag        string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ageGroup            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;age_grp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['age_grp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicity()

# %%
api = Enrollment().byRaceEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:22:22,014 - palet_log - INFO - adding byRaceEthnicity to by Group
# 2022-05-12 14:22:22,014 - palet_log - INFO - Adding By Group race_ethncty_flag
# Out[13]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'race': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','race'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicityExpanded()

# %%
api = Enrollment().byRaceEthnicityExpanded()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:23:18,820 - palet_log - INFO - adding byRaceEthnicityExpanded to by Group
# 2022-05-12 14:23:18,821 - palet_log - INFO - Adding By Group race_ethncty_exp_flag
# Out[18]: counter                   object
# race_ethncty_exp_flag     string
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# raceExpanded              object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_exp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'raceExpanded': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_exp_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','raceExpanded'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: counter                   object
# race_ethncty_exp_flag     string
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# raceExpanded              object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_exp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_exp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEthnicity()

# %%
api = Enrollment().byEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:24:03,255 - palet_log - INFO - adding byEthnicity to by Group
# 2022-05-12 14:24:03,255 - palet_log - INFO - Adding By Group ethncty_cd
# calling build race ethnicity
# Out[23]: counter             object
# ethncty_cd          string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ethnicity           object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'ethncty_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'ethnicity': 'object'
}
ser = pd.Series(data=d, index=['counter','ethncty_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','ethnicity'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: counter             object
# ethncty_cd          string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ethnicity           object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;ethncty_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['ethncty_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byGender()

# %%
api = Enrollment().byGender()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:25:16,822 - palet_log - INFO - adding byGender to by Group
# 2022-05-12 14:25:16,822 - palet_log - INFO - Adding By Group gndr_cd
# Out[28]: counter             object
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'gndr_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','gndr_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: counter             object
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;gndr_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['gndr_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byState()

# %%
api = Enrollment().byState()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:25:54,235 - palet_log - INFO - adding byState to the by Group
# 2022-05-12 14:25:54,235 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# Out[33]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;SUBMTG_STATE_CD&#39;]
# </div>

# %%
assert str(api.by_group) == "['SUBMTG_STATE_CD']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byIncomeBracket()

# %%
api = Enrollment().byIncomeBracket()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:26:18,611 - palet_log - INFO - adding byIncomeBracket to the by Group
# 2022-05-12 14:26:18,611 - palet_log - INFO - Adding By Group incm_cd
# Out[38]: counter             object
# incm_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# income              object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'incm_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'income': 'object'
}
ser = pd.Series(data=d, index=['counter','incm_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','income'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: counter             object
# incm_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# income              object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;incm_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['incm_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byYear()

# %%
api = Enrollment().byYear()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:26:49,208 - palet_log - INFO - adding byYear to the by Group
# Out[43]: counter             object
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','mdcd_enrollment','chip_enrollment','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: counter             object
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# byMonth()

# %%
api = Enrollment().byMonth()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:27:01,904 - palet_log - INFO - adding byMonth to the by Group
# Out[46]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# #### Derived by Groups - Column Check and derived_by_type_group Check

# %% [markdown]
# byEnrollmentType()

# %%
api = Enrollment().byEnrollmentType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:27:22,632 - palet_log - INFO - adding byEnrollmentType to the by Group
# Out[49]: counter                   object
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# enrollment_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'enrollment_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'enrollment_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','enrollment_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','enrollment_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: counter                   object
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# enrollment_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: [palet.EnrollmentType.EnrollmentType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EnrollmentType.EnrollmentType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byCoverageType()

# %%
api = Enrollment().byCoverageType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:30:40,638 - palet_log - INFO - adding CoverageType to the by Group
# Out[54]: counter                 object
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# coverage_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'coverage_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'coverage_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','coverage_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','coverage_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: counter                 object
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# coverage_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[57]: [palet.CoverageType.CoverageType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.CoverageType.CoverageType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEligibilityType()

# %%
api = Enrollment().byEligibilityType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:33:42,792 - palet_log - INFO - adding EligibilityType to the by Group
# Out[59]: counter                  object
# eligibility_type         object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# eligibility_category     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'eligibility_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'eligibility_category': 'object'
}
ser = pd.Series(data=d, index=['counter','eligibility_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','eligibility_category'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: counter                  object
# eligibility_type         object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# eligibility_category     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(str(api.derived_by_type_group))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&lt;class &#39;palet.EligibilityType.EligibilityType&#39;&gt;]
# </div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EligibilityType.EligibilityType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# #### Time Units

# %%
api = Enrollment().byMonth()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:36:17,789 - palet_log - INFO - adding byMonth to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Month</td><td>2017</td><td>1</td><td>81130519</td><td>2596684</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>2</td><td>81092003</td><td>2627980</td><td>-0.0</td><td>0.012</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>3</td><td>81138480</td><td>2650699</td><td>0.001</td><td>0.009</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>4</td><td>80994137</td><td>2655847</td><td>-0.002</td><td>0.002</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>5</td><td>80946334</td><td>2686072</td><td>-0.001</td><td>0.011</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>6</td><td>80806204</td><td>2691153</td><td>-0.002</td><td>0.002</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>7</td><td>80646933</td><td>2709951</td><td>-0.002</td><td>0.007</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>8</td><td>80698357</td><td>2731401</td><td>0.001</td><td>0.008</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>9</td><td>80452683</td><td>2746242</td><td>-0.003</td><td>0.005</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>10</td><td>80515777</td><td>2775155</td><td>0.001</td><td>0.011</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>11</td><td>80612193</td><td>2812288</td><td>0.001</td><td>0.013</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2017</td><td>12</td><td>80748398</td><td>2837749</td><td>0.002</td><td>0.009</td><td>NaN</td><td>NaN</td></tr><tr><td>In Month</td><td>2018</td><td>1</td><td>80829930</td><td>2865681</td><td>0.001</td><td>0.01</td><td>-0.004</td><td>0.104</td></tr><tr><td>In Month</td><td>2018</td><td>2</td><td>80654588</td><td>2886786</td><td>-0.002</td><td>0.007</td><td>-0.005</td><td>0.098</td></tr><tr><td>In Month</td><td>2018</td><td>3</td><td>80537449</td><td>2905926</td><td>-0.001</td><td>0.007</td><td>-0.007</td><td>0.096</td></tr><tr><td>In Month</td><td>2018</td><td>4</td><td>80358772</td><td>2908146</td><td>-0.002</td><td>0.001</td><td>-0.008</td><td>0.095</td></tr><tr><td>In Month</td><td>2018</td><td>5</td><td>80251042</td><td>2925838</td><td>-0.001</td><td>0.006</td><td>-0.009</td><td>0.089</td></tr><tr><td>In Month</td><td>2018</td><td>6</td><td>80008444</td><td>2930325</td><td>-0.003</td><td>0.002</td><td>-0.01</td><td>0.089</td></tr><tr><td>In Month</td><td>2018</td><td>7</td><td>79932654</td><td>2948637</td><td>-0.001</td><td>0.006</td><td>-0.009</td><td>0.088</td></tr><tr><td>In Month</td><td>2018</td><td>8</td><td>79786032</td><td>2635642</td><td>-0.002</td><td>-0.106</td><td>-0.011</td><td>-0.035</td></tr><tr><td>In Month</td><td>2018</td><td>9</td><td>79538231</td><td>2639381</td><td>-0.003</td><td>0.001</td><td>-0.011</td><td>-0.039</td></tr><tr><td>In Month</td><td>2018</td><td>10</td><td>79450064</td><td>2658704</td><td>-0.001</td><td>0.007</td><td>-0.013</td><td>-0.042</td></tr><tr><td>In Month</td><td>2018</td><td>11</td><td>79227582</td><td>2690282</td><td>-0.003</td><td>0.012</td><td>-0.017</td><td>-0.043</td></tr><tr><td>In Month</td><td>2018</td><td>12</td><td>79046638</td><td>2716990</td><td>-0.002</td><td>0.01</td><td>-0.021</td><td>-0.043</td></tr><tr><td>In Month</td><td>2019</td><td>1</td><td>79115997</td><td>2727980</td><td>0.001</td><td>0.004</td><td>-0.021</td><td>-0.048</td></tr><tr><td>In Month</td><td>2019</td><td>2</td><td>78979589</td><td>2749233</td><td>-0.002</td><td>0.008</td><td>-0.021</td><td>-0.048</td></tr><tr><td>In Month</td><td>2019</td><td>3</td><td>78951965</td><td>2758390</td><td>-0.0</td><td>0.003</td><td>-0.02 ...

# %%
assert (df['counter'] == 'In Month').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment().byYear()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-12 14:36:31,148 - palet_log - INFO - adding byYear to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Year</td><td>2017</td><td>95748823</td><td>4259367</td><td>NaN</td><td>NaN</td></tr><tr><td>In Year</td><td>2018</td><td>94605172</td><td>4556629</td><td>-0.012</td><td>0.07</td></tr><tr><td>In Year</td><td>2019</td><td>93217105</td><td>4363985</td><td>-0.015</td><td>-0.042</td></tr><tr><td>In Year</td><td>2020</td><td>93339719</td><td>3974170</td><td>0.001</td><td>-0.089</td></tr><tr><td>In Year</td><td>2021</td><td>99122714</td><td>3592476</td><td>0.062</td><td>-0.096</td></tr><tr><td>In Year</td><td>2022</td><td>96037156</td><td>2794045</td><td>-0.031</td><td>-0.222</td></tr></tbody></table></div>

# %%
assert (df['counter'] == 'In Year').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
><td>0.003</td><td>-0.01</td><td>0.087</td></tr><tr><td>Full Month</td><td>2018</td><td>7</td><td>79244913</td><td>2895776</td><td>-0.002</td><td>0.002</td><td>-0.01</td><td>0.087</td></tr><tr><td>Full Month</td><td>2018</td><td>8</td><td>79180427</td><td>2581770</td><td>-0.001</td><td>-0.108</td><td>-0.011</td><td>-0.039</td></tr><tr><td>Full Month</td><td>2018</td><td>9</td><td>78980554</td><td>2595293</td><td>-0.003</td><td>0.005</td><td>-0.012</td><td>-0.042</td></tr><tr><td>Full Month</td><td>2018</td><td>10</td><td>78853422</td><td>2605440</td><td>-0.002</td><td>0.004</td><td>-0.014</td><td>-0.045</td></tr><tr><td>Full Month</td><td>2018</td><td>11</td><td>78643502</td><td>2632184</td><td>-0.003</td><td>0.01</td><td>-0.017</td><td>-0.048</td></tr><tr><td>Full Month</td><td>2018</td><td>12</td><td>78491018</td><td>2672657</td><td>-0.002</td><td>0.015</td><td>-0.021</td><td>-0.046</td></tr><tr><td>Full Month</td><td>2019</td><td>1</td><td>78523864</td><td>2675149</td><td>0.0</td><td>0.001</td><td>-0.021</td><td>-0.05</td></tr><tr><td>Full Month</td><td>2019</td><td>2</td><td>78464574</td><td>2695483</td><td>-0.001</td><td>0.008</td><td>-0.02</td><td>-0.05</td></tr><tr><td>Full Month</td><td>2019</td><td>3</td><td>78389142</td><td>2710145</t ...

# %%
assert (df['counter'] == 'Full Month').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment()

api.timeunit = 'partial'

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>Partial Month</td><td>2017</td><td>1</td><td>602467</td><td>34543</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td></tr><tr><td>Partial Month</td><td>2017</td><td>2</td><td>575780</td><td>31900</td><td>-0.044</td><td>-0.077</td><td>NaN</td><td>NaN</td></tr><tr><td>Partial Month</td><td>2017</td><td>3</td><td>591221</td><td>34569</td><td>0.027</td><td>0.084</td><td>NaN</td><td>NaN</td></tr><tr><td>Partial Month</td><td>2017</td><td>4</td><td>544429</td><td>33910</td><td>-0.079</td><td>-0.019</td><td>NaN</td><td>NaN</td></tr><tr><td>Partial Month</td><td>2017</td><td>5</td><td>594930</td><td>39420</td><td>0.093</td><td>0.162</td><td>NaN</td><td>NaN</td></tr><tr><td>Partial Month</td><td>2017</td><td>6</td><td>579331</td><td>34519</td><td>-0.026</td><td>-0.124</td><td>NaN</td><td>NaN</td></tr><tr><td>Partial Month</td><td>2017</td><td>7</td><td>597763</td><td>45211</td><td>0.032</td><td>0.31</td><td>NaN</td><td>NaN</td></tr><tr><td>Partial Month</td><td>2017</td><td>8</td><td>610002</td><td>44914</td><td>0.02</td><td>-0.007</td><td>NaN</td><td>NaN</td></tr><