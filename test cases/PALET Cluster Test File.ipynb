# %%
import sys
sys.path.append('/dbfs/FileStore/shared_uploads/akira/lib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Cluster Test File
# Use Case: Run this file once a new version of PALET has been pushed to their respective cluster on either the PROD or VAL Servers
#
# Purpose: Does not return dataframes, this file is used to confirm that our assertations about the PALET library are correct.
#
# Functionality Testing:
#  - Paletable objects
#  - By Groups
#  - Derived By Groups
#  - Time Units
#  - Chronic Conidition
#  - Readmits*

# %%
# only required for std cluster, if testing dedicated PALET clusters do not run this cell
#import sys
#sys.path.append('/dbfs/FileStore/shared_uploads/akira/lib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from palet.Enrollment import Enrollment
from palet.Diagnoses import Diagnoses
from palet.ServiceCategory import ServiceCategory
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Paletable Objects - Column Check and Type Check

# %%
api = Enrollment()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %% [markdown]
# Column Check

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(type(api))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;palet.Enrollment.Enrollment&#39;&gt;
# </div>

# %% [markdown]
# Type Check

# %%
assert str(type(api)) == "<class 'palet.Enrollment.Enrollment'>", 'The Paletable object is not an Enrollment object.'
print('The Paletable object is an Enrollment object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Enrollment object.
# </div>

# %% [markdown]
# #### By Groups - Column Check and by_group Check

# %% [markdown]
# byAgeRange()

# %%
api = Enrollment().byAgeRange()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:49:02,677 - palet_log - INFO - adding byAgeRange to aggregate by Group
# 2022-05-13 13:49:02,677 - palet_log - INFO - Adding By Group age_grp_flag
# Out[9]: counter             object
# age_grp_flag        string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ageGroup            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'age_grp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'ageGroup': 'object'
}
ser = pd.Series(data=d, index=['counter','age_grp_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','ageGroup'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: counter             object
# age_grp_flag        string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ageGroup            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;age_grp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['age_grp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicity()

# %%
api = Enrollment().byRaceEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:50:59,009 - palet_log - INFO - adding byRaceEthnicity to by Group
# 2022-05-13 13:50:59,010 - palet_log - INFO - Adding By Group race_ethncty_flag
# Out[14]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'race': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','race'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicityExpanded()

# %%
api = Enrollment().byRaceEthnicityExpanded()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:52:18,582 - palet_log - INFO - adding byRaceEthnicityExpanded to by Group
# 2022-05-13 13:52:18,582 - palet_log - INFO - Adding By Group race_ethncty_exp_flag
# Out[19]: counter                   object
# race_ethncty_exp_flag     string
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# raceExpanded              object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_exp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'raceExpanded': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_exp_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','raceExpanded'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: counter                   object
# race_ethncty_exp_flag     string
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# raceExpanded              object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_exp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_exp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEthnicity()

# %%
api = Enrollment().byEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:53:11,106 - palet_log - INFO - adding byEthnicity to by Group
# 2022-05-13 13:53:11,106 - palet_log - INFO - Adding By Group ethncty_cd
# calling build race ethnicity
# Out[24]: counter             object
# ethncty_cd          string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ethnicity           object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'ethncty_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'ethnicity': 'object'
}
ser = pd.Series(data=d, index=['counter','ethncty_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','ethnicity'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: counter             object
# ethncty_cd          string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ethnicity           object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;ethncty_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['ethncty_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byGender()

# %%
api = Enrollment().byGender()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:53:50,322 - palet_log - INFO - adding byGender to by Group
# 2022-05-13 13:53:50,322 - palet_log - INFO - Adding By Group gndr_cd
# Out[29]: counter             object
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'gndr_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','gndr_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: counter             object
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;gndr_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['gndr_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byState()

# %%
api = Enrollment().byState()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:54:33,386 - palet_log - INFO - adding byState to the by Group
# 2022-05-13 13:54:33,387 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# Out[34]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;SUBMTG_STATE_CD&#39;]
# </div>

# %%
assert str(api.by_group) == "['SUBMTG_STATE_CD']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byIncomeBracket()

# %%
api = Enrollment().byIncomeBracket()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:55:18,645 - palet_log - INFO - adding byIncomeBracket to the by Group
# 2022-05-13 13:55:18,645 - palet_log - INFO - Adding By Group incm_cd
# Out[39]: counter             object
# incm_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# income              object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'incm_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'income': 'object'
}
ser = pd.Series(data=d, index=['counter','incm_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','income'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: counter             object
# incm_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# income              object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;incm_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['incm_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byYear()

# %%
api = Enrollment().byYear()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:56:05,317 - palet_log - INFO - adding byYear to the by Group
# Out[44]: counter             object
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','mdcd_enrollment','chip_enrollment','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: counter             object
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# byMonth()

# %%
api = Enrollment().byMonth()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:56:39,354 - palet_log - INFO - adding byMonth to the by Group
# Out[47]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# #### Derived by Groups - Column Check and derived_by_type_group Check

# %% [markdown]
# byEnrollmentType()

# %%
api = Enrollment().byEnrollmentType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 13:57:27,427 - palet_log - INFO - adding byEnrollmentType to the by Group
# Out[50]: counter                   object
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# enrollment_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'enrollment_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'enrollment_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','enrollment_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','enrollment_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: counter                   object
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# enrollment_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: [palet.EnrollmentType.EnrollmentType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EnrollmentType.EnrollmentType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byCoverageType()

# %%
api = Enrollment().byCoverageType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 14:03:35,349 - palet_log - INFO - adding CoverageType to the by Group
# Out[55]: counter                 object
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# coverage_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'coverage_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'coverage_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','coverage_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','coverage_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[56]: counter                 object
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# coverage_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: [palet.CoverageType.CoverageType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.CoverageType.CoverageType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEligibilityType()

# %%
api = Enrollment().byEligibilityType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 14:10:28,945 - palet_log - INFO - adding EligibilityType to the by Group
# Out[60]: counter                  object
# eligibility_type         object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# eligibility_category     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'eligibility_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'eligibility_category': 'object'
}
ser = pd.Series(data=d, index=['counter','eligibility_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','eligibility_category'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: counter                  object
# eligibility_type         object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# eligibility_category     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(str(api.derived_by_type_group))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&lt;class &#39;palet.EligibilityType.EligibilityType&#39;&gt;]
# </div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EligibilityType.EligibilityType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
td>0.063</td></tr><tr><td>In Month</td><td>2020</td><td>1</td><td>78374100</td><td>2920830</td><td>0.002</td><td>0.012</td><td>-0.009</td><td>0.071</td></tr><tr><td>In Month</td><td>2020</td><td>2</td><td>78520158</td><td>2931588</td><td>0.002</td><td>0.004</td><td>-0.006</td><td>0.066</td></tr><tr><td>In Month</td><td>2020</td><td>3</td><td>78625685</td><td>2936375</td><td>0.001</td> ...

# %%
assert (df['counter'] == 'In Month').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment().byYear()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 14:21:11,385 - palet_log - INFO - adding byYear to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Year</td><td>2018</td><td>94605172</td><td>4556629</td><td>null</td><td>null</td></tr><tr><td>In Year</td><td>2019</td><td>93217105</td><td>4363985</td><td>-0.015</td><td>-0.042</td></tr><tr><td>In Year</td><td>2020</td><td>93339719</td><td>3974170</td><td>0.001</td><td>-0.089</td></tr><tr><td>In Year</td><td>2021</td><td>99122714</td><td>3592476</td><td>0.062</td><td>-0.096</td></tr><tr><td>In Year</td><td>2022</td><td>96037156</td><td>2794045</td><td>-0.031</td><td>-0.222</td></tr></tbody></table></div>

# %%
assert (df['counter'] == 'In Year').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment()

api.timeunit = 'full'

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>Full Month</td><td>2018</td><td>1</td><td>80207942</td><td>2815972</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>2</td><td>80088312</td><td>2835884</td><td>-0.001</td><td>0.007</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>3</td><td>77304348</td><td>2868609</td><td>-0.035</td><td>0.012</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>4</td><td>77131911</td><td>2867218</td><td>-0.002</td><td>-0.0</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>5</td><td>79666571</td><td>2879876</td><td>0.033</td><td>0.004</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>6</td><td>79419950</td><td>2888844</td><td>-0.003</td><td>0.003</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>7</td><td>79244913</td><td>2895776</td><td>-0.002</td><td>0.002</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>8</td><td>79180427</td><td>2581770</td><td>-0.001</td><td>-0.108</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>9</td><td>78980554</td><td>2595293</td><td>-0.003</td><td>0.005</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>10</td><td>78853422</td><td>2605440</td><td>-0.002</td><td>0.004
td>46442</td><td>-0.004</td><td>-0.12</td><td>-0.006</td><td>0.048</td></tr><tr><td>Partial Month</td><td>2020</td><td>1</td><td>577293</td><td>51650</td><td>0.045</td><td>0.112</td><td>-0.025</td><td>-0.022</td></tr><tr><td>Partial Month</td><td>2020</td><td>2</td><td>831542</td><td>51266</td><td>0.44</td><td>-0.007</td><td>0.615</td><td>-0.046</td></tr><tr><td>Partial Month</td><td>2020</td><td>3</td><td>526788</td>< ...

# %%
assert (df['counter'] == 'Partial Month').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %% [markdown]
# ##### Diagnoses In-Depth Testing

# %%
AFib = ['I230', 'I231', 'I232', 'I233', 'I234', 'I235', 'I236', 'I237', 'I238', 'I213', 'I214', 'I219', 'I220',
                        'I221', 'I222', 'I228', 'I229', 'I21A1', 'I21A9', 'I2101', 'I2102', 'I2109', 'I2111', 'I2119', 'I2121', 'I2129']

Diabetes = [   'E0800','E0801','E0810','E0811','E0821','E0822','E0829','E08311','E08319','E08321','E083211','E083212','E083213',
                        'E083219','E08329','E083291','E083292','E083293','E083299','E08331','E083311','E083312','E083313','E083319','E08339']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
api = Enrollment().byMonth().having( \
                    Diagnoses.within([                     \
                    (ServiceCategory.inpatient, 1),        \
                    (ServiceCategory.other_services, 2)],  \
                        Diabetes))

display(api.fetch())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-13 14:27:33,785 - palet_log - INFO - adding byMonth to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Month</td><td>2018</td><td>1</td><td>5677</td><td>7</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>2</td><td>5684</td><td>7</td><td>0.001</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>3</td><td>5698</td><td>7</td><td>0.002</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>4</td><td>5732</td><td>6</td><td>0.006</td><td>-0.143</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>5</td><td>5747</td><td>6</td><td>0.003</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>6</td><td>5756</td><td>6</td><td>0.002</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>7</td><td>5785</td><td>5</td><td>0.005</td><td>-0.167</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>8</td><td>5813</td><td>5</td><td>0.005</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>9</td><td>5836</td><td>6</td><td>0.004</td><td>0.2</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>10</td><td>5852</td><td>6</td><td>0.003</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>11</td><td>5894</td><td>7</td><td>0.007</td><td>0.167</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>12</td><td>5903</td><td>7</td><td>0.002</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2019</td><td>1</td><td>5952</td><td>7</td><td>0.008</td><td>0.0</td><td>0.048</td><td>0.0</td></tr><tr><td>In Month</td><td>2019</td><td>2</td><td>5969</td><td>6</td><td>0.003</td><td>-0.143</td><td>0.05</td><td>-0.143</td></tr><tr><td>In Month</td><td>2019</td><td>3</td><td>5995</td><td>6</td><td>0.004</td><td>0.0</td><td>0.052</td><td>-0.143</td></tr><tr><td>In Month</td><td>2019</td><td>4</td><td>6017</td><td>5</td><td>0.004</td><td>-0.167</td><td>0.05</td><td>-0.167</td></tr><tr><td>In Month</td><td