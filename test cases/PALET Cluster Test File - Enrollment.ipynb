# %% [markdown]
# #### Cluster Test File - Enrollment
# Use Case: Run this file once a new version of PALET has been pushed to their respective cluster on either the PROD or VAL Servers
#
# Purpose: Does not return dataframes, this file is used to confirm that our assertations about the PALET library are correct.
#
# Functionality Testing:
#  - Paletable objects
#  - By Groups
#  - Derived By Groups
#  - Time Units

# %%
# only required for std cluster, if testing dedicated PALET clusters do not run this cell
import sys
sys.path.append('/dbfs/FileStore/shared_uploads/akira/lib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from palet.Enrollment import Enrollment
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Paletable Objects - Column Check and Type Check

# %%
api = Enrollment()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: counter            object
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %% [markdown]
# Column Check

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment'])
ser

#,'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: counter            object
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# Type Check

# %%
print(type(api))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;palet.Enrollment.Enrollment&#39;&gt;
# </div>

# %%
assert str(type(api)) == "<class 'palet.Enrollment.Enrollment'>", 'The Paletable object is not an Enrollment object.'
print('The Paletable object is an Enrollment object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Enrollment object.
# </div>

# %% [markdown]
# #### By Groups - Column Check and by_group Check

# %% [markdown]
# byAgeRange()

# %%
api = Enrollment().byAgeRange()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:17:45,873 - palet_log - INFO - adding byAgeRange to aggregate by Group
# 2022-06-02 22:17:45,878 - palet_log - INFO - Adding By Group age_grp_flag
# Out[8]: counter            object
# age_grp_flag       string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# ageGroup           object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'age_grp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'ageGroup': 'object'
}
ser = pd.Series(data=d, index=['counter','age_grp_flag','year','month','mdcd_enrollment','chip_enrollment','ageGroup'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: counter            object
# age_grp_flag       string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# ageGroup           object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;age_grp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['age_grp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicity()

# %%
api = Enrollment().byRaceEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:22:41,018 - palet_log - INFO - adding byRaceEthnicity to by Group
# 2022-06-02 22:22:41,018 - palet_log - INFO - Adding By Group race_ethncty_flag
# Out[13]: counter              object
# race_ethncty_flag    string
# year                 object
# month                 int32
# mdcd_enrollment       int64
# chip_enrollment       int64
# race                 object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'race': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_flag','year','month','mdcd_enrollment','chip_enrollment','race'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: counter              object
# race_ethncty_flag    string
# year                 object
# month                 int32
# mdcd_enrollment       int64
# chip_enrollment       int64
# race                 object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicityExpanded()

# %%
api = Enrollment().byRaceEthnicityExpanded()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:29:46,527 - palet_log - INFO - adding byRaceEthnicityExpanded to by Group
# 2022-06-02 22:29:46,528 - palet_log - INFO - Adding By Group race_ethncty_exp_flag
# Out[18]: counter                  object
# race_ethncty_exp_flag    string
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# raceExpanded             object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_exp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'raceExpanded': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_exp_flag','year','month','mdcd_enrollment','chip_enrollment','raceExpanded'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: counter                  object
# race_ethncty_exp_flag    string
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# raceExpanded             object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_exp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_exp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEthnicity()

# %%
api = Enrollment().byEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:34:00,019 - palet_log - INFO - adding byEthnicity to by Group
# 2022-06-02 22:34:00,019 - palet_log - INFO - Adding By Group ethncty_cd
# calling build race ethnicity
# Out[23]: counter            object
# ethncty_cd         string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# ethnicity          object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'ethncty_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'ethnicity': 'object'
}
ser = pd.Series(data=d, index=['counter','ethncty_cd','year','month','mdcd_enrollment','chip_enrollment','ethnicity'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: counter            object
# ethncty_cd         string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# ethnicity          object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;ethncty_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['ethncty_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byGender()

# %%
api = Enrollment().byGender()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:41:33,390 - palet_log - INFO - adding byGender to by Group
# 2022-06-02 22:41:33,390 - palet_log - INFO - Adding By Group gndr_cd
# Out[28]: counter            object
# gndr_cd            string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'gndr_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','gndr_cd','year','month','mdcd_enrollment','chip_enrollment'])
ser

# ,'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: counter            object
# gndr_cd            string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;gndr_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['gndr_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byState()

# %%
api = Enrollment().byState()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:44:20,972 - palet_log - INFO - adding byState to the by Group
# 2022-06-02 22:44:20,973 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# Out[33]: counter            object
# SUBMTG_STATE_CD    string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# STNAME             object
# STABBREV           object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','year','month','mdcd_enrollment','chip_enrollment','STNAME','STABBREV'])
ser

#,'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: counter            object
# SUBMTG_STATE_CD    string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# STNAME             object
# STABBREV           object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;SUBMTG_STATE_CD&#39;]
# </div>

# %%
assert str(api.by_group) == "['SUBMTG_STATE_CD']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byIncomeBracket()

# %%
api = Enrollment().byIncomeBracket()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:47:01,047 - palet_log - INFO - adding byIncomeBracket to the by Group
# 2022-06-02 22:47:01,047 - palet_log - INFO - Adding By Group incm_cd
# Out[38]: counter            object
# incm_cd            string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# income             object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'incm_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'income': 'object'
}
ser = pd.Series(data=d, index=['counter','incm_cd','year','month','mdcd_enrollment','chip_enrollment','income'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: counter            object
# incm_cd            string
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# income             object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;incm_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['incm_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byYear()

# %%
api = Enrollment().byYear()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:50:04,347 - palet_log - INFO - adding byYear to the by Group
# Out[43]: counter            object
# year               object
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','mdcd_enrollment','chip_enrollment'])
ser

#,'mdcd_pct_yoy','chip_pct_yoy'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: counter            object
# year               object
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# byMonth()

# %%
api = Enrollment().byMonth()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:50:41,804 - palet_log - INFO - adding byMonth to the by Group
# Out[46]: counter            object
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment'])
ser

#,'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: counter            object
# year               object
# month               int32
# mdcd_enrollment     int64
# chip_enrollment     int64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# #### Derived by Groups - Column Check and derived_by_type_group Check

# %% [markdown]
# byEnrollmentType()

# %%
api = Enrollment().byEnrollmentType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 22:52:45,458 - palet_log - INFO - adding byEnrollmentType to the by Group
# Out[49]: counter                  object
# enrollment_type          object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# enrollment_type_label    object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'enrollment_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'enrollment_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','enrollment_type','year','month','mdcd_enrollment','chip_enrollment','enrollment_type_label'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: counter                  object
# enrollment_type          object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# enrollment_type_label    object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: [palet.EnrollmentType.EnrollmentType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EnrollmentType.EnrollmentType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byCoverageType()

# %%
api = Enrollment().byCoverageType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 23:06:39,907 - palet_log - INFO - adding CoverageType to the by Group
# Out[54]: counter                object
# coverage_type          object
# year                   object
# month                   int32
# mdcd_enrollment         int64
# chip_enrollment         int64
# coverage_type_label    object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'coverage_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'coverage_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','coverage_type','year','month','mdcd_enrollment','chip_enrollment','coverage_type_label'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: counter                object
# coverage_type          object
# year                   object
# month                   int32
# mdcd_enrollment         int64
# chip_enrollment         int64
# coverage_type_label    object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[57]: [palet.CoverageType.CoverageType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.CoverageType.CoverageType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEligibilityType()

# %%
api = Enrollment().byEligibilityType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 23:21:59,477 - palet_log - INFO - adding EligibilityType to the by Group
# Out[59]: counter                 object
# eligibility_type        object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# eligibility_category    object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'eligibility_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
#   'mdcd_pct_mom': 'float64',
#   'chip_pct_mom': 'float64',
#   'mdcd_pct_yoy': 'float64',
#   'chip_pct_yoy': 'float64',
  'eligibility_category': 'object'
}
ser = pd.Series(data=d, index=['counter','eligibility_type','year','month','mdcd_enrollment','chip_enrollment','eligibility_category'])
ser

#'mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy',
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: counter                 object
# eligibility_type        object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# eligibility_category    object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: [palet.EligibilityType.EligibilityType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EligibilityType.EligibilityType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# #### Time Units

# %%
api = Enrollment().byMonth()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 23:45:16,491 - palet_log - INFO - adding byMonth to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th></tr></thead><tbody><tr><td>In Month</td><td>2018</td><td>1</td><td>80829930</td><td>2865681</td></tr><tr><td>In Month</td><td>2018</td><td>2</td><td>80654588</td><td>2886786</td></tr><tr><td>In Month</td><td>2018</td><td>3</td><td>80537449</td><td>2905926</td></tr><tr><td>In Month</td><td>2018</td><td>4</td><td>80358772</td><td>2908146</td></tr><tr><td>In Month</td><td>2018</td><td>5</td><td>80251042</td><td>2925838</td></tr><tr><td>In Month</td><td>2

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment().byYear()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 23:51:46,015 - palet_log - INFO - adding byYear to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>mdcd_enrollment</th><th>chip_enrollment</th></tr></thead><tbody><tr><td>In Year</td><td>2018</td><td>94605172</td><td>4556629</td></tr><tr><td>In Year</td><td>2019</td><td>93217105</td><td>4363985</td></tr><tr><td>In Year</td><td>2020</td><td>93339719</td><td>3974170</td></tr><tr><td>In Year</td><td>2021</td><td>99122714</td><td>3592476</td></tr><tr><td>In Year</td><td>2022</td><td>96037156</td><td>2794045</td></tr></tbody></table></div>

# %%
assert (df['counter'] == 'In Year').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment()

api.timeunit = 'full'

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th></tr></thead><tbody><tr><td>Full Month</td><td>2018</td><td>1</td><td>80207942</td><td>2815972</td></tr><tr><td>Full Month</td><td>2018</td><td>2</td><td>80088312</td><td>2835884</td></tr><tr><td>Full Month</td><td>2018</td><td>3</td><td>77304348</td><td>2868609</td></tr><tr><td>Full Month</td><td>2018</td><td>4</td><td>77131911</td><td>2867218</td></tr><tr><td>Full Month</td><td>2018</td><td>5</td><td>79666571</td><td>2879876</td></tr><tr><td>Full Month</td><td>2018</td><td>6</td><td>79419950</td><td>2888844</td></tr><tr><td>Full Month</td><td>2018</td><td>7</td><td>79244913</td><td>2895776</td></tr><tr><td>Full Month</td><td>2018</td><td>8</td><td>79180427</td><td>2581770</td></tr><tr><td>Full Month</td><td>2018</td><td>9</td><td>78980554</td><td>2595293</td></tr><tr><td>Full Month</td><td>2018</td><td>10</td><td>78853422</td><td>2605440</td></tr><tr><td>Full Month</td><td>2018</td><td>11</td><td>78643502</td><td>2632184</td></tr><tr><td>Full Month</td><td>2018</td><td>12</td><td>78491018</td><td>2672657</td></tr><tr><td>Full Month</td><td>2019</td><td>1</td><td>78523864</td><td>2675149</td></tr><tr><td>Full Month</td><td>2019</td><td>2</td><td>78464574</td><td>2695483</td></tr><tr><td>Full Month</td><td>2019</td><td>3</td><td>78389142</td><td>2710145</td></tr><tr><td>Full Month</td><td>2019</td><td>4</td><td>78286942</td><td>2705634</td></tr><tr><td>Full Month</td><td>2019</td><td>5</td><td>78149605</td><td>2718528</td></tr><tr><td>Full Month</td><td>2019</td><td>6</td><td>78031477</td><td>2729701</td></tr><tr><td>Full Month</td><td>2019</td><td>7</td><td>77999858</td><td>2737785</td></tr><tr><td>Full Month</td><td>2019</td><td>8</td><td>77992683</td><td>2757577</td></tr><tr><td>Full Month</td><td>2019</td><td>9</td><td>77935747</td><td>2779361</td></tr><tr><td>Full Month</td><td>2019