# %% [markdown]
# #### Cluster Test File - Combining Features
#
# Use Case: Run this file once a new version of PALET has been pushed to their respective cluster on either the PROD or VAL Servers
#
# Purpose: This notebook differs from the other notebooks in the PALET Cluster Test Suite. It does not focus on unit testing or assertions. Instead this notebook is meant to act as a stress test for PALET by combining as many features as possible.

# %%
# only required for std cluster, if testing dedicated PALET clusters do not run this cell
import sys
sys.path.append('/dbfs/FileStore/shared_uploads/akira/lib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from palet.Enrollment import Enrollment
from palet.Readmits import Readmits
from palet.Diagnoses import Diagnoses
from palet.ServiceCategory import ServiceCategory
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
api = Enrollment(period='year').byState(['CA'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 19:42:47,132 - palet_log - INFO - adding byState to the by Group
# 2022-06-02 19:42:47,132 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# </div>

# %%
print(api.sql())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#                 select
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,
#
#
#                     bb.de_fil_dt as year,
#
#
#
#                     sum(mdcd_enrollment) as mdcd_enrollment,
#                     sum(chip_enrollment) as chip_enrollment
#                 from (
#                     select
#                         aa.SUBMTG_STATE_CD
# 			   ,
#                         aa.de_fil_dt,
#                         aa.submtg_state_cd as with_submtg_state_cd,
#                         aa.msis_ident_num,
#
#
#                 &#39;In Year&#39; as counter,
#                 stack(1,
#                     1,
#                         sum(case when aa.mdcd_enrlmt_days_yr &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_yr &gt; 0 then 1 else 0 end)
#                     ) as (year,  mdcd_enrollment, chip_enrollment)
#
#                     from
#                         taf.taf_ann_de_base as aa
#
#                     where
#                         aa.da_run_id in ( 7355,7354,7426,7425,7424 ) and
#                         (
#                 (aa.mdcd_enrlmt_days_yr &gt; 0) or (aa.chip_enrlmt_days_yr &gt; 0)
#             ) and
#                         aa.SUBMTG_STATE_CD in (&#39;06&#39;)
#                     group by
#                         aa.SUBMTG_STATE_CD
# 			   ,
#
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                     order by
#                         aa.SUBMTG_STATE_CD
# 			   ,
#
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                 ) as bb
#
#
#
#                 where
#                     1=1 and
#                     bb.SUBMTG_STATE_CD in (&#39;06&#39;) and
#                     1=1
#
#                 group by
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,
#
#
#
#
#                     bb.de_fil_dt
#                 order by
#                     bb.SUBMTG_STATE_CD
# 			   ,
#
#
#
#
#                     bb.de_fil_dt
#
# </div>

# %%
df = api.fetch()
display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:300: UserWarning: createDataFrame attempted Arrow optimization because &#39;spark.sql.execution.arrow.pyspark.enabled&#39; is set to true; however, failed by the reason below:
#   Cannot specify a mask or a size when passing an object that is converted with the __arrow_array__ protocol.
# Attempting non-optimization as &#39;spark.sql.execution.arrow.pyspark.fallback.enabled&#39; is set to true.
#   warnings.warn(msg)
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>year</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>STNAME</th><th>STABBREV</th></tr></thead><tbody><tr><td>In Year</td><td>06</td><td>2018</td><td>16910830</td><td>33154</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2019</td><td>16388292</td><td>35354</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2020</td><td>15750591</td><td>30867</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2021</td><td>16142905</td><td>27800</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2022</td><td>15243325</td><td>19729</td><td>California</td><td>CA</td></tr></tbody></table></div>

# %%
df = api.byMonth()
display(df.fetch())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 19:43:43,312 - palet_log - INFO - adding byMonth to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>STNAME</th><th>STABBREV</th></tr></thead><tbody><tr><td>In Month</td><td>06</td><td>2018</td><td>1</td><td>14475941</td><td>16680</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>2</td><td>14431559</td><td>16924</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>3</td><td>14403347</td><td>17315</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>4</td><td>14337772</td><td>17818</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>5</td><td>14289290</td><td>18176</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>6</td><td>14226677</td><td>18177</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>7</td><td>14200450</td><td>18500</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>8</td><td>14192033</td><td>17533</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>9</td><td>14126320</td><td>17629</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>10</td><td>14108034</td><td>18063</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>11</td><td>14055800</td><td>18424</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2018</td><td>12</td><td>14003365</td><td>18960</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>1</td><td>13998836</td><td>19681</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>2</td><td>13943110</td><td>19670</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>3</td><td>13925095</td><td>19876</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>4</td><td>13863514</td><td>20051</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>5</td><td>13821622</td><td>20202</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>6</td><td>13768424</td><td>20202</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>7</td><td>13754036</td><td>20253</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>8</td><td>13754342</td><td>20316</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>9</td><td>13709469</td><td>20796</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>10</td><td>13673473</td><td>22619</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>11</td><td>13592783</td><td>20174</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2019</td><td>12</td><td>13537703</td><td>19858</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2020</td><td>1</td><td>13537443</td><td>20637</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2020</td><td>2</td><td>13469445</td><td>21175</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2020</td><td>3</td><td>13405629</td><td>21867</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2020</td><td>4</td><td>13462749</td><td>22265</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2020</td><td>5</td><td>13556376</td><td>22372</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2020</td><td>6</td><td>13651927</td><td>21795</td><td>California</td><td>CA</td></tr><tr><td>In Month</td><td>06</td><td>2020</td><td>7</td><td>13762761</td><td>21400< ...

# %%
print(api.sql())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#                 select
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,
#
#
#
#                 bb.de_fil_dt as year,
#                 bb.month,
#
#
#
#
#                     sum(mdcd_enrollment) as mdcd_enrollment,
#                     sum(chip_enrollment) as chip_enrollment
#                 from (
#                     select
#                         aa.SUBMTG_STATE_CD
# 			   ,
#                         aa.de_fil_dt,
#                         aa.submtg_state_cd as with_submtg_state_cd,
#                         aa.msis_ident_num,
#
#
#                     &#39;In Month&#39; as counter,
#                     stack(12,
#                         1,
#                         sum(case when aa.mdcd_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         2,
#                         sum(case when aa.mdcd_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         3,
#                         sum(case when aa.mdcd_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         4,
#                         sum(case when aa.mdcd_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         5,
#                         sum(case when aa.mdcd_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         6,
#                         sum(case when aa.mdcd_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         7,
#                         sum(case when aa.mdcd_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         8,
#                         sum(case when aa.mdcd_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         9,
#                         sum(case when aa.mdcd_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         10,
#                         sum(case when aa.mdcd_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         11,
#                         sum(case when aa.mdcd_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         12,
#                         sum(case when aa.mdcd_enrlmt_days_12 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_12 &gt; 0 then 1 else 0 end)
#                     ) as (month,  mdcd_enrollment, chip_enrollment)
#
#                     from
#                         taf.taf_ann_de_base as aa
#
#                     where
#                         aa.da_run_id in ( 7355,7354,7426,7425,7424 ) and
#                         (
#                 ((aa.mdcd_enrlmt_days_01 &gt; 0) or (aa.chip_enrlmt_days_01 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_02 &gt; 0) or (aa.chip_enrlmt_days_02 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_03 &gt; 0) or (aa.chip_enrlmt_days_03 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_04 &gt; 0) or (aa.chip_enrlmt_days_04 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_05 &gt; 0) or (aa.chip_enrlmt_days_05 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_06 &gt; 0) or (aa.chip_enrlmt_days_06 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_07 &gt; 0) or (aa.chip_enrlmt_days_07 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_08 &gt; 0) or (aa.chip_enrlmt_days_08 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_09 &gt; 0) or (aa.chip_enrlmt_days_09 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_10 &gt; 0) or (aa.chip_enrlmt_days_10 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_11 &gt; 0) or (aa.chip_enrlmt_days_11 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_12 &gt; 0) or (aa.chip_enrlmt_days_12 &gt; 0))
#             ) and
#                         aa.SUBMTG_STATE_CD in (&#39;06&#39;)
#                     group by
#                         aa.SUBMTG_STATE_CD
# 			   ,
#
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                     order by
#                         aa.SUBMTG_STATE_CD
# 			   ,
#
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                 ) as bb
#
#
#
#                 where
#                     1=1 and
#                     bb.SUBMTG_STATE_CD in (&#39;06&#39;) and
#                     1=1
#
#                 group by
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,
#
#
#
#
#
#                 bb.de_fil_dt,
#                 bb.month
#
#                 order by
#                     bb.SUBMTG_STATE_CD
# 			   ,
#
#
#
#
#
#                 bb.de_fil_dt,
#                 bb.month
#
#
# </div>

# %%
df = api.byEthnicity()
display(df.fetch())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 19:45:33,765 - palet_log - INFO - adding byEthnicity to by Group
# 2022-06-02 19:45:33,765 - palet_log - INFO - Adding By Group ethncty_cd
# calling build race ethnicity
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>ethncty_cd</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>STNAME</th><th>STABBREV</th><th>ethnicity</th></tr></thead><tbody><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>1</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>2</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>3</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>4</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>5</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>6</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>7</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>8</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>9</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>10</td><td>43507</td><td>103</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>11</td><td>89952</td><td>252</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2020</td><td>12</td><td>131177</td><td>399</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>1</td><td>167938</td><td>597</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>2</td><td>191230</td><td>692</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>3</td><td>234272</td><td>810</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>4</td><td>279632</td><td>899</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>5</td><td>311867</td><td>1060</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>6</td><td>341884</td><td>1259</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>7</td><td>374814</td><td>1375</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>8</td><td>418286</td><td>1462</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>9</td><td>452081</td><td>1546</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>10</td><td>479060</td><td>1607</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>11</td><td>502609</td><td>1679</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2021</td><td>12</td><td>530424</td><td>1798</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2022</td><td>1</td><td>560916</td><td>1896</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2022</td><td>2</td><td>570082</td><td>1950</td><td>California</td><td>CA</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>2022</td><td>3</t ...

# %%
print(api.sql())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#                 select
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#
#
#
#                 bb.de_fil_dt as year,
#                 bb.month,
#
#
#
#
#                     sum(mdcd_enrollment) as mdcd_enrollment,
#                     sum(chip_enrollment) as chip_enrollment
#                 from (
#                     select
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         aa.de_fil_dt,
#                         aa.submtg_state_cd as with_submtg_state_cd,
#                         aa.msis_ident_num,
#
#
#                     &#39;In Month&#39; as counter,
#                     stack(12,
#                         1,
#                         sum(case when aa.mdcd_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         2,
#                         sum(case when aa.mdcd_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         3,
#                         sum(case when aa.mdcd_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         4,
#                         sum(case when aa.mdcd_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         5,
#                         sum(case when aa.mdcd_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         6,
#                         sum(case when aa.mdcd_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         7,
#                         sum(case when aa.mdcd_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         8,
#                         sum(case when aa.mdcd_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         9,
#                         sum(case when aa.mdcd_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         10,
#                         sum(case when aa.mdcd_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         11,
#                         sum(case when aa.mdcd_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         12,
#                         sum(case when aa.mdcd_enrlmt_days_12 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_12 &gt; 0 then 1 else 0 end)
#                     ) as (month,  mdcd_enrollment, chip_enrollment)
#
#                     from
#                         taf.taf_ann_de_base as aa
#
#                     where
#                         aa.da_run_id in ( 7355,7354,7426,7425,7424 ) and
#                         (
#                 ((aa.mdcd_enrlmt_days_01 &gt; 0) or (aa.chip_enrlmt_days_01 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_02 &gt; 0) or (aa.chip_enrlmt_days_02 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_03 &gt; 0) or (aa.chip_enrlmt_days_03 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_04 &gt; 0) or (aa.chip_enrlmt_days_04 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_05 &gt; 0) or (aa.chip_enrlmt_days_05 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_06 &gt; 0) or (aa.chip_enrlmt_days_06 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_07 &gt; 0) or (aa.chip_enrlmt_days_07 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_08 &gt; 0) or (aa.chip_enrlmt_days_08 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_09 &gt; 0) or (aa.chip_enrlmt_days_09 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_10 &gt; 0) or (aa.chip_enrlmt_days_10 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_11 &gt; 0) or (aa.chip_enrlmt_days_11 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_12 &gt; 0) or (aa.chip_enrlmt_days_12 &gt; 0))
#             ) and
#                         aa.SUBMTG_STATE_CD in (&#39;06&#39;)
#                     group by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                     order by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                 ) as bb
#
#
#
#                 where
#                     1=1 and
#                     bb.SUBMTG_STATE_CD in (&#39;06&#39;) and
#                     1=1
#
#                 group by
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#
#
#
#
#
#                 bb.de_fil_dt,
#                 bb.month
#
#                 order by
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#
#
#
#
#
#                 bb.de_fil_dt,
#                 bb.month
#
#
# </div>

# %%
df = api.byEnrollmentType()
display(df.fetch())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-06-02 19:47:06,974 - palet_log - INFO - adding byEnrollmentType to the by Group
# calling build race ethnicity
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>ethncty_cd</th><th>enrollment_type</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>STNAME</th><th>STABBREV</th><th>ethnicity</th><th>enrollment_type_label</th></tr></thead><tbody><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>1</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>2</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>3</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>4</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>5</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>6</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>7</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>8</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>9</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>10</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>11</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>12</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>1</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>2</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>3</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>4</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>5</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>6</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>7</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>8</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>9</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>10</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>11</td><td>0</td><td>0</td><td ...

# %%
print(api.sql())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#                 select
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#                     bb.enrollment_type,
#
#
#                 bb.de_fil_dt as year,
#                 bb.month,
#
#
#
#
#                     sum(mdcd_enrollment) as mdcd_enrollment,
#                     sum(chip_enrollment) as chip_enrollment
#                 from (
#                     select
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         aa.de_fil_dt,
#                         aa.submtg_state_cd as with_submtg_state_cd,
#                         aa.msis_ident_num,
#
#
#                     &#39;In Month&#39; as counter,
#                     stack(12,
#                         1, aa.chip_cd_01,
#                         sum(case when aa.mdcd_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         2, aa.chip_cd_02,
#                         sum(case when aa.mdcd_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         3, aa.chip_cd_03,
#                         sum(case when aa.mdcd_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         4, aa.chip_cd_04,
#                         sum(case when aa.mdcd_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         5, aa.chip_cd_05,
#                         sum(case when aa.mdcd_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         6, aa.chip_cd_06,
#                         sum(case when aa.mdcd_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         7, aa.chip_cd_07,
#                         sum(case when aa.mdcd_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         8, aa.chip_cd_08,
#                         sum(case when aa.mdcd_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         9, aa.chip_cd_09,
#                         sum(case when aa.mdcd_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         10, aa.chip_cd_10,
#                         sum(case when aa.mdcd_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         11, aa.chip_cd_11,
#                         sum(case when aa.mdcd_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         12, aa.chip_cd_12,
#                         sum(case when aa.mdcd_enrlmt_days_12 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_12 &gt; 0 then 1 else 0 end)
#                     ) as (month, enrollment_type, mdcd_enrollment, chip_enrollment)
#
#                     from
#                         taf.taf_ann_de_base as aa
#
#                     where
#                         aa.da_run_id in ( 7355,7354,7426,7425,7424 ) and
#                         (
#                 ((aa.mdcd_enrlmt_days_01 &gt; 0) or (aa.chip_enrlmt_days_01 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_02 &gt; 0) or (aa.chip_enrlmt_days_02 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_03 &gt; 0) or (aa.chip_enrlmt_days_03 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_04 &gt; 0) or (aa.chip_enrlmt_days_04 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_05 &gt; 0) or (aa.chip_enrlmt_days_05 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_06 &gt; 0) or (aa.chip_enrlmt_days_06 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_07 &gt; 0) or (aa.chip_enrlmt_days_07 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_08 &gt; 0) or (aa.chip_enrlmt_days_08 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_09 &gt; 0) or (aa.chip_enrlmt_days_09 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_10 &gt; 0) or (aa.chip_enrlmt_days_10 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_11 &gt; 0) or (aa.chip_enrlmt_days_11 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_12 &gt; 0) or (aa.chip_enrlmt_days_12 &gt; 0))
#             ) and
#                         aa.SUBMTG_STATE_CD in (&#39;06&#39;)
#                     group by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         chip_cd_01
# 			   ,chip_cd_02
# 			   ,chip_cd_03
# 			   ,chip_cd_04
# 			   ,chip_cd_05
# 			   ,chip_cd_06
# 			   ,chip_cd_07
# 			   ,chip_cd_08
# 			   ,chip_cd_09
# 			   ,chip_cd_10
# 			   ,chip_cd_11
# 			   ,chip_cd_12
# 			   ,
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                     order by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         chip_cd_01
# 			   ,chip_cd_02
# 			   ,chip_cd_03
# 			   ,chip_cd_04
# 			   ,chip_cd_05
# 			   ,chip_cd_06
# 			   ,chip_cd_07
# 			   ,chip_cd_08
# 			   ,chip_cd_09
# 			   ,chip_cd_10
# 			   ,chip_cd_11
# 			   ,chip_cd_12
# 			   ,
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                 ) as bb
#
#
#
#                 where
#                     1=1 and
#                     bb.SUBMTG_STATE_CD in (&#39;06&#39;) and
#                     1=1
#
#                 group by
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#
#                     bb.enrollment_type,
#
#
#
#                 bb.de_fil_dt,
#                 bb.month
#
#                 order by
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#
#                     bb.enrollment_type,
#
#
#
#                 bb.de_fil_dt,
#                 bb.month
#
#
# </div>

# %%
Diabetes = [   'E0800','E0801','E0810','E0811','E0821','E0822','E0829','E08311','E08319','E08321','E083211','E083212','E083213','E083219','E08329','E083291','E083292','E083293','E083299','E08331','E083311','E083312','E083313','E083319','E08339','E083391','E083392','E083393','E083399','E08341','E083411','E083412','E083413','E083419','E08349','E083491','E083492','E083493','E083499','E08351','E083511','E083512','E083513','E083519','E083521','E083522','E083523','E083529','E083531','E083532','E083533','E083539','E083541','E083542','E083543','E083549','E083551','E083552','E083553','E083559','E08359','E083591','E083592','E083593','E083599','E0836','E0837X1','E0837X2','E0837X3','E0837X9','E0839','E0840','E0841','E0842','E0843','E0844','E0849','E0851','E0852','E0859','E08610','E08618','E08620','E08621','E08622','E08628','E08630','E08638','E08641','E08649','E0865','E0869','E088','E089','E0900','E0901','E0910','E0911','E0921','E0922','E0929','E09311','E09319','E09321','E093211','E093212','E093213','E093219','E09329','E093291','E093292','E093293','E093299','E09331','E093311','E093312','E093313','E093319','E09339','E093391','E093392','E093393','E093399','E09341','E093411','E093412','E093413','E093419','E09349','E093491','E093492','E093493','E093499','E09351','E093511','E093512','E093513','E093519','E093521','E093522','E093523','E093529','E093531','E093532','E093533','E093539','E093541','E093542','E093543','E093549','E093551','E093552','E093553','E093559','E09359','E093591','E093592','E093593','E093599','E0936','E0937X1','E0937X2','E0937X3','E0937X9','E0939','E0940','E0941','E0942','E0943','E0944','E0949','E0951','E0952','E0959','E09610','E09618','E09620','E09621','E09622','E09628','E09630','E09638','E09641','E09649','E0965','E0969','E098','E099','E1010','E1011','E1021','E1022','E1029','E10311','E10319','E10321','E103211','E103212','E103213','E103219','E10329','E103291','E103292','E103293','E103299','E10331','E103311','E103312','E103313','E103319','E10339','E103391','E103392','E103393','E103399','E10341','E103411','E103412','E103413','E103419','E10349','E103491','E103492','E103493','E103499','E10351','E103511','E103512','E103513','E103519','E10359','E1036','E1037X1','E1037X2','E1037X3','E1037X9','E1039','E1040','E1041','E1042','E1043','E1044','E1049','E1051','E1052','E1059','E10610','E10618','E10620','E10621','E10622','E10628','E10630','E10638','E10641','E10649','E1065','E1069','E108','E109','E1100','E1101','E1110','E1111','E1121','E1122','E1129','E11311','E11319','E11321','E113211','E113212','E113213','E113219','E11329','E113291','E113292','E113293','E113299','E11331','E113311','E113312','E113313','E113319','E11339','E113391','E113392','E113393','E113399','E11341','E113411','E113412','E113413','E113419','E11349','E113491','E113492','E113493','E113499','E11351','E113511','E113512','E113513','E113519','E113521','E113522','E113523','E113529','E113531','E113532','E113533','E113539','E113541','E113542','E113543','E113549','E113551','E113552','E113553','E113559','E11359','E113591','E113592','E113593','E113599','E1136','E1137X1','E1137X2','E1137X3','E1137X9','E1139','E1140','E1141','E1142','E1143','E1144','E1149','E1151','E1152','E1159','E11610','E11618','E11620','E11621','E11622','E11628','E11630','E11638','E11641','E11649','E1165','E1169','E118','E119','E1300','E1301','E1310','E1311','E1321','E1322','E1329','E13311','E13319','E13321','E133211','E133212','E133213','E133219','E13329','E133291','E133292','E133293','E133299','E13331','E133311','E133312','E133313','E133319','E13339','E133391','E133392','E133393','E133399','E13341','E133411','E133412','E133413','E133419','E13349','E133491','E133492','E133493','E133499','E13351','E133511','E133512','E133513','E133519','E133521','E133522','E133523','E133529','E133531','E133532','E133533','E133539','E133541','E133542','E133543','E133549','E133551','E133552','E133553','E133559','E13359','E1336','E1339','E1340','E1341','E1342','E1343','E1344','E1349','E1351','E1352','E1359','E13610','E13618','E13620','E13621','E13622','E13628','E13630','E13638','E13641','E13649','E1365','E1369','E138','E139']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = api.mark(Diagnoses.where(ServiceCategory.other_services, Diabetes), 'Diabetes')
display(df.fetch())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">calling build race ethnicity
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>ethncty_cd</th><th>enrollment_type</th><th>year</th><th>month</th><th>Diabetes</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>STNAME</th><th>STABBREV</th><th>ethnicity</th><th>enrollment_type_label</th></tr></thead><tbody><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>1</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>2</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>3</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>4</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>5</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>6</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>7</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>8</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>9</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>10</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>11</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>12</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>1</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>2</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>3</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>4</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>5</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>6</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>7</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>8</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>9</td><td>0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>- ...

# %%
print(api.sql())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#                 select
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#                     bb.enrollment_type,
#
#
#                 bb.de_fil_dt as year,
#                 bb.month,
#
#                     coalesce(9J7KrvmC.indicator, 0) as Diabetes,
#
#
#                     sum(mdcd_enrollment) as mdcd_enrollment,
#                     sum(chip_enrollment) as chip_enrollment
#                 from (
#                     select
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         aa.de_fil_dt,
#                         aa.submtg_state_cd as with_submtg_state_cd,
#                         aa.msis_ident_num,
#
#
#                     &#39;In Month&#39; as counter,
#                     stack(12,
#                         1, aa.chip_cd_01,
#                         sum(case when aa.mdcd_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         2, aa.chip_cd_02,
#                         sum(case when aa.mdcd_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         3, aa.chip_cd_03,
#                         sum(case when aa.mdcd_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         4, aa.chip_cd_04,
#                         sum(case when aa.mdcd_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         5, aa.chip_cd_05,
#                         sum(case when aa.mdcd_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         6, aa.chip_cd_06,
#                         sum(case when aa.mdcd_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         7, aa.chip_cd_07,
#                         sum(case when aa.mdcd_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         8, aa.chip_cd_08,
#                         sum(case when aa.mdcd_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         9, aa.chip_cd_09,
#                         sum(case when aa.mdcd_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         10, aa.chip_cd_10,
#                         sum(case when aa.mdcd_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         11, aa.chip_cd_11,
#                         sum(case when aa.mdcd_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         12, aa.chip_cd_12,
#                         sum(case when aa.mdcd_enrlmt_days_12 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_12 &gt; 0 then 1 else 0 end)
#                     ) as (month, enrollment_type, mdcd_enrollment, chip_enrollment)
#
#                     from
#                         taf.taf_ann_de_base as aa
#
#                     where
#                         aa.da_run_id in ( 7355,7354,7426,7425,7424 ) and
#                         (
#                 ((aa.mdcd_enrlmt_days_01 &gt; 0) or (aa.chip_enrlmt_days_01 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_02 &gt; 0) or (aa.chip_enrlmt_days_02 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_03 &gt; 0) or (aa.chip_enrlmt_days_03 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_04 &gt; 0) or (aa.chip_enrlmt_days_04 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_05 &gt; 0) or (aa.chip_enrlmt_days_05 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_06 &gt; 0) or (aa.chip_enrlmt_days_06 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_07 &gt; 0) or (aa.chip_enrlmt_days_07 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_08 &gt; 0) or (aa.chip_enrlmt_days_08 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_09 &gt; 0) or (aa.chip_enrlmt_days_09 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_10 &gt; 0) or (aa.chip_enrlmt_days_10 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_11 &gt; 0) or (aa.chip_enrlmt_days_11 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_12 &gt; 0) or (aa.chip_enrlmt_days_12 &gt; 0))
#             ) and
#                         aa.SUBMTG_STATE_CD in (&#39;06&#39;)
#                     group by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         chip_cd_01
# 			   ,chip_cd_02
# 			   ,chip_cd_03
# 			   ,chip_cd_04
# 			   ,chip_cd_05
# 			   ,chip_cd_06
# 			   ,chip_cd_07
# 			   ,chip_cd_08
# 			   ,chip_cd_09
# 			   ,chip_cd_10
# 			   ,chip_cd_11
# 			   ,chip_cd_12
# 			   ,
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                     order by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         chip_cd_01
# 			   ,chip_cd_02
# 			   ,chip_cd_03
# 			   ,chip_cd_04
# 			   ,chip_cd_05
# 			   ,chip_cd_06
# 			   ,chip_cd_07
# 			   ,chip_cd_08
# 			   ,chip_cd_09
# 			   ,chip_cd_10
# 			   ,chip_cd_11
# 			   ,chip_cd_12
# 			   ,
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                 ) as bb
#
#
# left join
#                 ((
#                 select distinct
#                     submtg_state_cd,
#                     msis_ident_num,
#                     min(1) as indicator,
#                     count(distinct ot_link_key) as m
#                 from
#                     taf.data_anltcs_taf_oth_vw
#                 where
#                     da_run_id in ( 7340,7339,7338 )
#                     and (
#                         ( dgns_1_cd in (&#39;E0800&#39;,&#39;E0801&#39;,&#39;E0810&#39;,&#39;E0811&#39;,&#39;E0821&#39;,&#39;E0822&#39;,&#39;E0829&#39;,&#39;E08311&#39;,&#39;E08319&#39;,&#39;E08321&#39;,&#39;E083211&#39;,&#39;E083212&#39;,&#39;E083213&#39;,&#39;E083219&#39;,&#39;E08329&#39;,&#39;E083291&#39;,&#39;E083292&#39;,&#39;E083293&#39;,&#39;E083299&#39;,&#39;E08331&#39;,&#39;E083311&#39;,&#39;E083312&#39;,&#39;E083313&#39;,&#39;E083319&#39;,&#39;E08339&#39;,&#39;E083391&#39;,&#39;E083392&#39;,&#39;E083393&#39;,&#39;E083399&#39;,&#39;E08341&#39;,&#39;E083411&#39;,&#39;E083412&#39;,&#39;E083413&#39;,&#39;E083419&#39;,&#39;E08349&#39;,&#39;E083491&#39;,&#39;E083492&#39;,&#39;E083493&#39;,&#39;E083499&#39;,&#39;E08351&#39;,&#39;E083511&#39;,&#39;E083512&#39;,&#39;E083513&#39;,&#39;E083519&#39;,&#39;E083521&#39;,&#39;E083522&#39;,&#39;E083523&#39;,&#39;E083529&#39;,&#39;E083531&#39;,&#39;E083532&#39;,&#39;E083533&#39;,&#39;E083539&#39;,&#39;E083541&#39;,&#39;E083542&#39;,&#39;E083543&#39;,&#39;E083549&#39;,&#39;E083551&#39;,&#39;E083552&#39;,&#39;E083553&#39;,&#39;E083559&#39;,&#39;E08359&#39;,&#39;E083591&#39;,&#39;E083592&#39;,&#39;E083593&#39;,&#39;E083599&#39;,&#39;E0836&#39;,&#39;E0837X1&#39;,&#39;E0837X2&#39;,&#39;E0837X

# %%
df = api.calculate(Readmits.allcause(30))
display(df.fetch())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">calling build race ethnicity
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>ethncty_cd</th><th>enrollment_type</th><th>year</th><th>month</th><th>Diabetes</th><th>readmits</th><th>admits</th><th>readmit_rate</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>STNAME</th><th>STABBREV</th><th>ethnicity</th><th>enrollment_type_label</th></tr></thead><tbody><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>1</td><td>0</td><td>1.0</td><td>3.0</td><td>0.3333</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>2</td><td>0</td><td>3.0</td><td>5.0</td><td>0.6</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>3</td><td>0</td><td>2.0</td><td>2.0</td><td>1.0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>4</td><td>0</td><td>1.0</td><td>2.0</td><td>0.5</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>5</td><td>0</td><td>1.0</td><td>2.0</td><td>0.5</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>6</td><td>0</td><td>1.0</td><td>2.0</td><td>0.5</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>7</td><td>0</td><td>3.0</td><td>9.0</td><td>0.3333</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>8</td><td>0</td><td>12.0</td><td>24.0</td><td>0.5</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>9</td><td>0</td><td>27.0</td><td>91.0</td><td>0.2967</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>10</td><td>0</td><td>15.0</td><td>46.0</td><td>0.3261</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>11</td><td>0</td><td>14.0</td><td>48.0</td><td>0.2917</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2020</td><td>12</td><td>0</td><td>0.0</td><td>4.0</td><td>0.0</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>1</td><td>0</td><td>25.0</td><td>83.0</td><td>0.3012</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>2</td><td>0</td><td>17.0</td><td>62.0</td><td>0.2742</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>3</td><td>0</td><td>25.0</td><td>80.0</td><td>0.3125</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>4</td><td>0</td><td>25.0</td><td>91.0</td><td>0.2747</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>06</td><td>-1</td><td>null</td><td>2021</td><td>5</td><td>0</td><td>22.0</td><td>78.0</td><td>0.2821</td><td>0</td><td>0</td><td>California</td><td>CA</td><td>null</td><td>null</td></tr><tr> ...

# %%
print(api.sql())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#                 select
#                     counter,
#                     bb.SUBMTG_STATE_CD
# 			   ,bb.ethncty_cd
# 			   ,
#                     bb.enrollment_type,
#
#
#                 bb.de_fil_dt as year,
#                 bb.month,
#
#                     coalesce(9J7KrvmC.indicator, 0) as Diabetes,
#
#             sum(f23AzP19.has_readmit) as readmits,
#             sum(f23AzP19.has_admit) as admits,
#             round(sum(f23AzP19.has_readmit) / sum(f23AzP19.has_admit), 4) as readmit_rate,
#
#
#                     sum(mdcd_enrollment) as mdcd_enrollment,
#                     sum(chip_enrollment) as chip_enrollment
#                 from (
#                     select
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         aa.de_fil_dt,
#                         aa.submtg_state_cd as with_submtg_state_cd,
#                         aa.msis_ident_num,
#
#
#                     &#39;In Month&#39; as counter,
#                     stack(12,
#                         1, aa.chip_cd_01,
#                         sum(case when aa.mdcd_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_01 &gt; 0 then 1 else 0 end),
#                         2, aa.chip_cd_02,
#                         sum(case when aa.mdcd_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_02 &gt; 0 then 1 else 0 end),
#                         3, aa.chip_cd_03,
#                         sum(case when aa.mdcd_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_03 &gt; 0 then 1 else 0 end),
#                         4, aa.chip_cd_04,
#                         sum(case when aa.mdcd_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_04 &gt; 0 then 1 else 0 end),
#                         5, aa.chip_cd_05,
#                         sum(case when aa.mdcd_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_05 &gt; 0 then 1 else 0 end),
#                         6, aa.chip_cd_06,
#                         sum(case when aa.mdcd_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_06 &gt; 0 then 1 else 0 end),
#                         7, aa.chip_cd_07,
#                         sum(case when aa.mdcd_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_07 &gt; 0 then 1 else 0 end),
#                         8, aa.chip_cd_08,
#                         sum(case when aa.mdcd_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_08 &gt; 0 then 1 else 0 end),
#                         9, aa.chip_cd_09,
#                         sum(case when aa.mdcd_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_09 &gt; 0 then 1 else 0 end),
#                         10, aa.chip_cd_10,
#                         sum(case when aa.mdcd_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_10 &gt; 0 then 1 else 0 end),
#                         11, aa.chip_cd_11,
#                         sum(case when aa.mdcd_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_11 &gt; 0 then 1 else 0 end),
#                         12, aa.chip_cd_12,
#                         sum(case when aa.mdcd_enrlmt_days_12 &gt; 0 then 1 else 0 end),
#                         sum(case when aa.chip_enrlmt_days_12 &gt; 0 then 1 else 0 end)
#                     ) as (month, enrollment_type, mdcd_enrollment, chip_enrollment)
#
#                     from
#                         taf.taf_ann_de_base as aa
#
#                     where
#                         aa.da_run_id in ( 7355,7354,7426,7425,7424 ) and
#                         (
#                 ((aa.mdcd_enrlmt_days_01 &gt; 0) or (aa.chip_enrlmt_days_01 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_02 &gt; 0) or (aa.chip_enrlmt_days_02 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_03 &gt; 0) or (aa.chip_enrlmt_days_03 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_04 &gt; 0) or (aa.chip_enrlmt_days_04 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_05 &gt; 0) or (aa.chip_enrlmt_days_05 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_06 &gt; 0) or (aa.chip_enrlmt_days_06 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_07 &gt; 0) or (aa.chip_enrlmt_days_07 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_08 &gt; 0) or (aa.chip_enrlmt_days_08 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_09 &gt; 0) or (aa.chip_enrlmt_days_09 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_10 &gt; 0) or (aa.chip_enrlmt_days_10 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_11 &gt; 0) or (aa.chip_enrlmt_days_11 &gt; 0)) or
#                 ((aa.mdcd_enrlmt_days_12 &gt; 0) or (aa.chip_enrlmt_days_12 &gt; 0))
#             ) and
#                         aa.SUBMTG_STATE_CD in (&#39;06&#39;)
#                     group by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         chip_cd_01
# 			   ,chip_cd_02
# 			   ,chip_cd_03
# 			   ,chip_cd_04
# 			   ,chip_cd_05
# 			   ,chip_cd_06
# 			   ,chip_cd_07
# 			   ,chip_cd_08
# 			   ,chip_cd_09
# 			   ,chip_cd_10
# 			   ,chip_cd_11
# 			   ,chip_cd_12
# 			   ,
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                     order by
#                         aa.SUBMTG_STATE_CD
# 			   ,aa.ethncty_cd
# 			   ,
#                         chip_cd_01
# 			   ,chip_cd_02
# 			   ,chip_cd_03
# 			   ,chip_cd_04
# 			   ,chip_cd_05
# 			   ,chip_cd_06
# 			   ,chip_cd_07
# 			   ,chip_cd_08
# 			   ,chip_cd_09
# 			   ,chip_cd_10
# 			   ,chip_cd_11
# 			   ,chip_cd_12
# 			   ,
#
#                         aa.de_fil_dt,
#                         with_submtg_state_cd,
#                         aa.msis_ident_num
#                 ) as bb
#
#
# left join
#                 ((
#                 select distinct
#                     submtg_state_cd,
#                     msis_ident_num,
#                     min(1) as indicator,
#                     count(distinct ot_link_key) as m
#                 from
#                     taf.data_anltcs_taf_oth_vw
#                 where
#                     da_run_id in ( 7340,7339,7338 )
#                     and (
#                         ( dgns_1_cd in (&#39;E0800&#39;,&#39;E0801&#39;,&#39;E0810&#39;,&#39;E0811&#39;,&#39;E0821&#39;,&#39;E0822&#39;,&#39;E0829&#39;,&#39;E08311&#39;,&#39;E08319&#39;,&#39;E08321&#39;,&#39;E083211&#39;,&#39;E083212&#39;,&#39;E083213&#39;,&#39;E083219&#39;,&#39;E08329&#39;,&#39;E083291&#39;,&#39;E083292&#39;,&#39;E083293&#39;,&#39;E083299&#39;,&#39;E08331&#39;,&#39;E083311&#39;,&#39;E083312&#39;,&#39;E083313&#39;,&#39;E083319&#39;,&#39;E08339&#39;,&#39;E083391&#39;,&#39;E083392&#39;,&#39;E083393&#39;,&#39;E083399&#39;,&#39;E08341&#39;,&#39;E083411&#39;,&#39;E083412&#39;,&#39;E083413&#39;,&#39;E083419&#39;,&#39;E08349&#39;,&#39;E083491&#39;,&#39;E083492&#39;,&#39;E083493&#39;,&#39;E083499&#39;,&#39;E08351&#39;,&#39;E083511&#39;,&#39;E083512&#39;,&#39;E083513&#39;,&#39;E083519&#39;,&#39;E083521&#39;,&#39;E083522&#39;,&#39;E083523&#39;,&#39;E083529&#39;,&#39;E083531&#39;,&#39;E083532&#39;,&#39;E083533&#39;,&#39;E083539&#39;,&#39;E083541&#39;,&#39;E083542&#39;,&#39;E083543&#39;,&#39;E083549&#39;,&#39;E083551&#39;,&#39;E08
