# %% [markdown]
# #### Cluster Test File
# Use Case: Run this file once a new version of PALET has been pushed to their respective cluster on either the PROD or VAL Servers
#
# Purpose: Does not return dataframes, this file is used to confirm that our assertations about the PALET library are correct.
#
# Functionality Testing:
#  - Paletable objects
#  - By Groups
#  - Derived By Groups
#  - Time Units
#  - Chronic Conidition
#  - Readmits*

# %%
# only required for std cluster, if testing dedicated PALET clusters do not run this cell
#import sys
#sys.path.append('/dbfs/FileStore/shared_uploads/akira/lib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from palet.Enrollment import Enrollment
from palet.Diagnoses import Diagnoses
from palet.ServiceCategory import ServiceCategory
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Paletable Objects - Column Check and Type Check

# %%
api = Enrollment()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:13:37,639 - palet_log - RELEASE - PALET Library Release Notes
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - Version 1.9.20220511
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** Improved speed of elibigility by reducing unneeded run_ids when filtering by byYear
# 2022-05-11 18:13:37,640 - palet_log - RELEASE -
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - Version 1.9.20220504
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** All cause Readmits now allows for lookback and timeframe
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** When visible, patient status will now add a column with code to value conversion
# 2022-05-11 18:13:37,640 - palet_log - RELEASE -
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - Version 1.8.20220428
# 2022-05-11 18:13:37,640 - palet_log - RELEASE -
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** Fixed filtering for all by Groups to allow for list of values. i.e. [&#39;01&#39;, &#39;02&#39;, ... ,&#39;10&#39;]
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** Now able to filter byYear and byMonth at the same time
# 2022-05-11 18:13:37,640 - palet_log - RELEASE -
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - Version 1.8.20220425
# 2022-05-11 18:13:37,640 - palet_log - RELEASE -
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** Added this message on first Palet startup w/ version number
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** Fixed byAgeRange to display column of the specified range(s)
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** Added a warning to byAgeRange, byCoverageType, byEnrollmentType, byEligibilityType
# 2022-05-11 18:13:37,640 - palet_log - RELEASE -     functions if the input is not dict and display an example input
# 2022-05-11 18:13:37,640 - palet_log - RELEASE - *** Moved Eligibility into enrollment via byEligibilityType()
# 2022-05-11 18:13:37,641 - palet_log - RELEASE - *** DEPRECATED: Eligibility class. Use Paletable.byEligibilityType()
# 2022-05-11 18:13:37,641 - palet_log - RELEASE - *** Fixed filtering byCoverageType, byEligibilityType, byEnrollmentType
# 2022-05-11 18:13:37,641 - palet_log - RELEASE - *** Fix mom and yoy column calculations
# 2022-05-11 18:13:37,641 - palet_log - RELEASE -
# 2022-05-11 18:13:37,641 - palet_log - RELEASE - --end of release--
# Out[3]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %% [markdown]
# Column Check

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(type(api))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;palet.Enrollment.Enrollment&#39;&gt;
# </div>

# %% [markdown]
# Type Check

# %%
assert str(type(api)) == "<class 'palet.Enrollment.Enrollment'>", 'The Paletable object is not an Enrollment object.'
print('The Paletable object is an Enrollment object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Enrollment object.
# </div>

# %% [markdown]
# #### By Groups - Column Check and by_group Check

# %% [markdown]
# byAgeRange()

# %%
api = Enrollment().byAgeRange()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:17:28,655 - palet_log - INFO - adding byAgeRange to aggregate by Group
# 2022-05-11 18:17:28,655 - palet_log - INFO - Adding By Group age_grp_flag
# Out[8]: counter             object
# age_grp_flag        string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ageGroup            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'age_grp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'ageGroup': 'object'
}
ser = pd.Series(data=d, index=['counter','age_grp_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','ageGroup'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: counter             object
# age_grp_flag        string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ageGroup            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;age_grp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['age_grp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicity()

# %%
api = Enrollment().byRaceEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:18:37,566 - palet_log - INFO - adding byRaceEthnicity to by Group
# 2022-05-11 18:18:37,566 - palet_log - INFO - Adding By Group race_ethncty_flag
# Out[13]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'race': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','race'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byRaceEthnicityExpanded()

# %%
api = Enrollment().byRaceEthnicityExpanded()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:19:28,166 - palet_log - INFO - adding byRaceEthnicityExpanded to by Group
# 2022-05-11 18:19:28,166 - palet_log - INFO - Adding By Group race_ethncty_exp_flag
# Out[18]: counter                   object
# race_ethncty_exp_flag     string
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# raceExpanded              object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_exp_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'raceExpanded': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_exp_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','raceExpanded'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: counter                   object
# race_ethncty_exp_flag     string
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# raceExpanded              object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;race_ethncty_exp_flag&#39;]
# </div>

# %%
assert str(api.by_group) == "['race_ethncty_exp_flag']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEthnicity()

# %%
api = Enrollment().byEthnicity()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:20:04,208 - palet_log - INFO - adding byEthnicity to by Group
# 2022-05-11 18:20:04,208 - palet_log - INFO - Adding By Group ethncty_cd
# calling build race ethnicity
# Out[23]: counter             object
# ethncty_cd          string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ethnicity           object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'ethncty_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'ethnicity': 'object'
}
ser = pd.Series(data=d, index=['counter','ethncty_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','ethnicity'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: counter             object
# ethncty_cd          string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# ethnicity           object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;ethncty_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['ethncty_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byGender()

# %%
api = Enrollment().byGender()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:20:55,032 - palet_log - INFO - adding byGender to by Group
# 2022-05-11 18:20:55,033 - palet_log - INFO - Adding By Group gndr_cd
# Out[28]: counter             object
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'gndr_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','gndr_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: counter             object
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;gndr_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['gndr_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byState()

# %%
api = Enrollment().byState()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:21:44,686 - palet_log - INFO - adding byState to the by Group
# 2022-05-11 18:21:44,687 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# Out[33]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;SUBMTG_STATE_CD&#39;]
# </div>

# %%
assert str(api.by_group) == "['SUBMTG_STATE_CD']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byIncomeBracket()

# %%
api = Enrollment().byIncomeBracket()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:22:15,308 - palet_log - INFO - adding byIncomeBracket to the by Group
# 2022-05-11 18:22:15,308 - palet_log - INFO - Adding By Group incm_cd
# Out[38]: counter             object
# incm_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# income              object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'incm_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'income': 'object'
}
ser = pd.Series(data=d, index=['counter','incm_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','income'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: counter             object
# incm_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# income              object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
print(api.by_group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;incm_cd&#39;]
# </div>

# %%
assert str(api.by_group) == "['incm_cd']", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byYear()

# %%
api = Enrollment().byYear()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:22:44,963 - palet_log - INFO - adding byYear to the by Group
# Out[43]: counter             object
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','mdcd_enrollment','chip_enrollment','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: counter             object
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# byMonth()

# %%
api = Enrollment().byMonth()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 18:23:02,936 - palet_log - INFO - adding byMonth to the by Group
# Out[46]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# #### Derived by Groups - Column Check and derived_by_type_group Check

# %% [markdown]
# byEnrollmentType()

# %%
api = Enrollment().byEnrollmentType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 21:05:31,866 - palet_log - INFO - adding byEnrollmentType to the by Group
# Out[56]: counter                   object
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# enrollment_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'enrollment_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'enrollment_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','enrollment_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','enrollment_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[57]: counter                   object
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# enrollment_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[59]: [palet.EnrollmentType.EnrollmentType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EnrollmentType.EnrollmentType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byCoverageType()

# %%
api = Enrollment().byCoverageType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 21:13:39,423 - palet_log - INFO - adding CoverageType to the by Group
# Out[61]: counter                 object
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# coverage_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'coverage_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'coverage_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','coverage_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','coverage_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: counter                 object
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# coverage_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[64]: [palet.CoverageType.CoverageType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.CoverageType.CoverageType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# byEligibilityType()

# %%
api = Enrollment().byEligibilityType()

df = api.fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 21:21:13,187 - palet_log - INFO - adding EligibilityType to the by Group
# Out[66]: counter                  object
# eligibility_type         object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# eligibility_category     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'eligibility_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'eligibility_category': 'object'
}
ser = pd.Series(data=d, index=['counter','eligibility_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','eligibility_category'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[67]: counter                  object
# eligibility_type         object
# year                     object
# month                     int32
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# eligibility_category     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
api.derived_by_type_group
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[69]: [palet.EligibilityType.EligibilityType]</div>

# %%
assert str(api.derived_by_type_group) == "[<class 'palet.EligibilityType.EligibilityType'>]", 'The Paletable object does not have the expected by group.'
print('The Paletable object has the expected by group.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object has the expected by group.
# </div>

# %% [markdown]
# #### Time Units

# %%
api = Enrollment().byMonth()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 21:29:07,822 - palet_log - INFO - adding byMonth to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Month</td><td>2017</td><td>1</td><td>81130519</td><td>2596684</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>2</td><td>81092003</td><td>2627980</td><td>-0.0</td><td>0.012</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>3</td><td>81138480</td><td>2650699</td><td>0.001</td><td>0.009</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>4</td><td>80994137</td><td>2655847</td><td>-0.002</td><td>0.002</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>5</td><td>80946334</td><td>2686072</td><td>-0.001</td><td>0.011</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>6</td><td>80806204</td><td>2691153</td><td>-0.002</td><td>0.002</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>7</td><td>80646933</td><td>2709951</td><td>-0.002</td><td>0.007</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>8</td><td>80698357</td><td>2731401</td><td>0.001</td><td>0.008</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>9</td><td>80452683</td><td>2746242</td><td>-0.003</td><td>0.005</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>10</td><td>80515777</td><td>2775155</td><td>0.001</td><td>0.011</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>11</td><td>80612193</td><td>2812288</td><td>0.001</td><td>0.013</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2017</td><td>12</td><td>80748398</td><td>2837749</td><td>0.002</td><td>0.009</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2018</td><td>1</td><td>80829930</td><td>2865681</td><td>0.001</td><td>0.01</td><td>-0.004</td><td>0.104</td></tr><tr><td>In Month</td><td>2018</td><td>2</td><td>80654588</td><td>2886786</td><td>-0.002</td><td>0.007</td><td>-0.005</td><td>0.098</td></tr><tr><td>In Month</td><td>2018</td><td>3</td><td>80537449</td><td>2905926</td><td>-0.001</td><td>0.007</td><td>-0.007</td><td>0.096</td></tr><tr><td>In Month</td><td>2018</td><td>4</td><td>80358772</td><td>2908146</td><td>-0.002</td><td>0.001</td><td>-0.008</td><td>0.095</td></tr><tr><td>In Month</td><td>2018</td><td>5</td><td>80251042</td><td>2925838</td><td>-0.001</td><td>0.006</td><td>-0.009</td><td>0.089</td></tr><tr><td>In Month</td><td>2018</td><td>6</td><td>80008444</td><td>2930325</td><td>-0.003</td><td>0.002</td><td>-0.01</td><td>0.089</td></tr><tr><td>In Month</td><td>2018</td><td>7</td><td>79932654</td><td>2948637</td><td>-0.001</td><td>0.006</td><td>-0.009</td><td>0.088</td></tr><tr><td>In Month</td><td>2018</td><td>8</td><td>79786032</td><td>2635642</td><td>-0.002</td><td>-0.106</td><td>-0.011</td><td>-0.035</td></tr><tr><td>In Month</td><td>2018</td><td>9</td><td>79538231</td><td>2639381</td><td>-0.003</td><td>0.001</td><td>-0.011</td><td>-0.039</td></tr><tr><td>In Month</td><td>2018</td><td>10</td><td>79450064</td><td>2658704</td><td>-0.001</td><td>0.007</td><td>-0.013</td><td>-0.042</td></tr><tr><td>In Month</td><td>2018</td><td>11</td><td>79227582</td><td>2690282</td><td>-0.003</td><td>0.012</td><td>-0.017</td><td>-0.043</td></tr><tr><td>In Month</td><td>2018</td><td>12</td><td>79046638</td><td>2716990</td><td>-0.002</td><td>0.01</td><td>-0.021</td><td>-0.043</td></tr><tr><td>In Month</td><td>2019</td><td>1</td><td>79115997</td><td>2727980</td><td>0.001</td><td>0.004</td><td>-0.021</td><td>-0.048</td></tr><tr><td>In Month</td><td>2019</td><td>2</td><td>78979589</td><td>2749233</td><td>-0.002</td><td>0.008</td><td>-0.021</td><td>-0.048</td></tr><tr><td>In Month</td><td>2019</td><td>3</td><td>78951965</td><td>2758390</td><td>-0.0</ ...

# %%
assert (df['counter'] == 'In Month').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment().byYear()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-11 21:29:55,410 - palet_log - INFO - adding byYear to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Year</td><td>2017</td><td>95748823</td><td>4259367</td><td>null</td><td>null</td></tr><tr><td>In Year</td><td>2018</td><td>94605172</td><td>4556629</td><td>-0.012</td><td>0.07</td></tr><tr><td>In Year</td><td>2019</td><td>93217105</td><td>4363985</td><td>-0.015</td><td>-0.042</td></tr><tr><td>In Year</td><td>2020</td><td>93339719</td><td>3974170</td><td>0.001</td><td>-0.089</td></tr><tr><td>In Year</td><td>2021</td><td>98976263</td><td>3589216</td><td>0.06</td><td>-0.097</td></tr><tr><td>In Year</td><td>2022</td><td>94967551</td><td>2593740</td><td>-0.041</td><td>-0.277</td></tr></tbody></table></div>

# %%
assert (df['counter'] == 'In Year').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment()

api.timeunit = 'full'

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>Full Month</td><td>2017</td><td>1</td><td>80528052</td><td>2562141</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>2</td><td>80516223</td><td>2596080</td><td>-0.0</td><td>0.013</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>3</td><td>80547259</td><td>2616130</td><td>0.0</td><td>0.008</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>4</td><td>80449708</td><td>2621937</td><td>-0.001</td><td>0.002</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>5</td><td>80351404</td><td>2646652</td><td>-0.001</td><td>0.009</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>6</td><td>80226873</td><td>2656634</td><td>-0.002</td><td>0.004</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>7</td><td>80049170</td><td>2664740</td><td>-0.002</td><td>0.003</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>8</td><td>80088355</td><td>2686487</td><td>0.0</td><td>0.008</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>9</td><td>79900959</td><td>2709839</td><td>-0.002</td><td>0.009</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>10</td><td>79939659</td><td>2729166</td><td>0.0</td><td>0.007</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>11</td><td>80040019</td><td>2763783</td><td>0.001</td><td>0.013</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2017</td><td>12</td><td>80201652</td><td>2801955</td><td>0.002</td><td>0.014</td><td>null</td><td>null</td></tr><tr><td>Full Month</td><td>2018</td><td>1</td><td>80207942</td><td>2815972</td><td>0.0</td><td>0.005</td><td>-0.004</td><td>0.099</td></tr><tr><td>Full Month</td><td>2018</td><td>2</td><td>80088312</td><td>2835884</td><td>-0.001</td><td>0.007</td><td>-0.005</td><td>0.092</td></tr><tr><td>Full Month</td><td>2018</td><td>3</td><td>77304348</td><td>2868609</td><td>-0.035</td><td>0.012</td><td>-0.04</td><td>0.097</td></tr><tr><td>Full Month</td><td>2018</td><td>4</td><td>77131911</td><td>2867218</td><td>-0.002</td><td>-0.0</td><td>-0.041</td><td>0.094</td></tr><tr><td>Full Month</td><td>2018</td><td>5</td><td>79666571</td><td>2879876</td><td>0.033</td><td>0.004</td><td>-0.009</td><td>0.088</td></tr><tr><td>Full Month</td><td>2018</td><td>6</td><td>79419950</td><td>2888844</td><td>-0.003</td><td>0.003</td><td>-0.01</td><td>0.087</td></tr><tr><td>Full Month</td><td>2018</td><td>7</td><td>79244913</td><td>2895776</td><td>-0.002</td><td>0.002</td><td>-0.01</td><td>0.087</td></tr><tr><td>Full Month</td><td>2018</td><td>8</td><td>79180427</td><td>2581770</td><td>-0.001</td><td>-0.108</td><td>-0.011</td><td>-0.039</td></tr><tr><td>Full Month</td><td>2018</td><td>9</td><td>78980554</td><td>2595293</td><td>-0.003</td><td>0.005</td><td>-0.012</td><td>-0.042</td></tr><tr><td>Full Month</td><td>2018</td><td>10</td><td>78853422</td><td>2605440</td><td>-0.002</td><td>0.004</td><td>-0.014</td><td>-0.045</td></tr><tr><td>Full Month</td><td>2018</td><td>11</td><td>78643502</td><td>2632184</td><td>-0.003</td><td>0.01</td><td>-0.017</td><td>-0.048</td></tr><tr><td>Full Month</td><td>2018</td><td>12</td><td>78491018</td><td>2672657</td><td>-0.002</td><td>0.015</td><td>-0.021</td><td>-0.046</td></tr><tr><td>Full Month</td><td>2019</td><td>1</td><td>78523864</td><td>2675149</td><td>0.0</td><td>0.001</td><td>-0.021</td><td>-0.05</td></tr><tr><td>Full Month</td><td>2019</td><td>2</td><td>78464574</td><td>2695483</td><td>-0.001</td><td>0.008</td><td>-0.02</td><td>-0.05</td></tr><tr><td>Full Month</td><td>2019</td><td>3</td><td>7 ...

# %%
assert (df['counter'] == 'Full Month').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object returns the expected time unit
# </div>

# %%
api = Enrollment()

api.timeunit = 'partial'

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ParseException</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-423179&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> api<span class="ansi-blue-fg">.</span>timeunit <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;partial&#39;</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>
# <span class="ansi-green-fg">----&gt; 5</span><span class="ansi-red-fg"> </span>df <span class="ansi-blue-fg">=</span> api<span class="ansi-blue-fg">.</span>fetch<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span> display<span class="ansi-blue-fg">(</span>df<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/dbfs/FileStore/shared_uploads/akira/lib/palet/Paletable.py</span> in <span class="ansi-cyan-fg">fetch</span><span class="ansi-blue-fg">(self)</span>
# <span class="ansi-green-intense-fg ansi-bold">    983</span>         &#34;&#34;&#34;
# <span class="ansi-green-intense-fg ansi-bold">    984</span>         <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql <span class="ansi-green-fg">import</span> SparkSession
# <span class="ansi-green-fg">--&gt; 985</span><span class="ansi-red-fg">         </span>session <span class="ansi-blue-fg">=</span> SparkSession<span class="ansi-blue-fg">.</span>getActiveSession<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    986</span>         <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">.</span>types <span class="ansi-green-fg">import</span> StringType
# <span class="ansi-green-intense-fg ansi-bold">    987</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/session.py</span> in <span class="ansi-cyan-fg">sql</span><span class="ansi-blue-fg">(self, sqlQuery)</span>
# <span class="ansi-green-intense-fg ansi-bold">    775</span>         <span class="ansi-blue-fg">[</span>Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row1&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row2&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row3&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">    776</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 777</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jsparkSession<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">(</span>sqlQuery<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>_wrapped<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    778</span>
# <span class="ansi-green-intense-fg ansi-bold">    779</span>     <span class="ansi-green-fg">def</span> table<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> tableName<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">ParseException</span>:
# extraneous input &#39;e&#39; expecting {&#39;)&#39;, &#39;,&#39;}(line 68, pos 96)
#
# == SQL ==
#
#                 select
#                     counter,
#
#
#
#
#                     de_fil_dt as year,
#                     month,
#
#
#
#                     sum(mdcd_enrollment) as mdcd_enrollment,
#                     sum(chip_enrollment) as chip_enrollment
#                 from (
#                     select
#
#                         aa.de_fil_dt,
#
#
#                     &#39;Partial Month&#39; as counter,
#                     stack(12,
#                         1,
#                         sum(case when aa.mdcd_enrlmt_days_01 between 1 and 30 then 1 else 0 end) ,
#                         sum(case when aa.chip_enrlmt_days_01 between 1 and 30 then 1 else 0 end) ,
#                         2,
#                         sum(case
#                                 when aa.mdcd_enrlmt_days_02 between 1 and 27 then 1
#                                 when (aa.mdcd_enrlmt_days_02 = 28
#                                     and ((aa.de_fil_dt % 4 = 0) or ((aa.de_fil_dt % 100 = 0)
#                                     and (aa.de_fil_dt % 400 = 0)))) then 1
#                                 else 0 end),
#                         sum(case
#                                 when aa.chip_enrlmt_days_02 between 1 and 27 then 1
#                                 when (aa.chip_enrlmt_days_02 = 28
#                                     and ((aa.de_fil_dt % 4 = 0) or ((aa.de_fil_dt % 100== 0)

# %%
assert (df['counter'] == 'Partial Month').all(), 'Enrollment object does not return the expected time unit'
print('Enrollment object returns the expected time unit')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AssertionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-423178&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span><span class="ansi-green-fg">assert</span> <span class="ansi-blue-fg">(</span>df<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;counter&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#39;Partial Month&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>all<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;Enrollment object does not return the expected time unit&#39;</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Enrollment object returns the expected time unit&#39;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AssertionError</span>: Enrollment object does not return the expected time unit</div>
