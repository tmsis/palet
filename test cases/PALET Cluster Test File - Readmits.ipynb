# %% [markdown]
# #### Cluster Test File - Readmits
#
# Use Case: Run this file once a new version of PALET has been pushed to their respective cluster on either the PROD or VAL Servers
#
# This file is used to confirm that our assertations about the PALET library are correct.
#
# Test Run - Spark, No Pandas - Focusing in on One State
# 1. Readmits using calculate()
# 2. Readmits using having()
#
# Unit Testing and Assertions:
# 1. Type check
# 2. having()
# 3. calculate()
# 4. Time units
# 5. By groups

# %%
# only required for std cluster, if testing dedicated PALET clusters do not run this cell
import sys
sys.path.append('/dbfs/FileStore/shared_uploads/akira/lib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from palet.Enrollment import Enrollment
from palet.Readmits import Readmits
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Test Run

# %%
# rate = Enrollment().calculate(Readmits.allcause(30))
rate = Enrollment().byState(['NY']).calculate(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 17:48:28,473 - palet_log - INFO - adding byState to the by Group
# 2022-05-31 17:48:28,473 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# </div>

# %%
# having = Enrollment().having(Readmits.allcause(30))
having = Enrollment().byState(['NY']).having(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 17:48:43,596 - palet_log - INFO - adding byState to the by Group
# 2022-05-31 17:48:43,596 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# </div>

# %%
rates = rate.fetch(False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
havings = having.fetch(False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Readmits with calculate()

# %%
display(rates)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>year</th><th>month</th><th>readmits</th><th>admits</th><th>readmit_rate</th><th>mdcd_enrollment</th><th>chip_enrollment</th></tr></thead><tbody><tr><td>In Month</td><td>36</td><td>2018</td><td>1</td><td>15128</td><td>87835</td><td>0.1722</td><td>6174153</td><td>589313</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>2</td><td>13380</td><td>77192</td><td>0.1733</td><td>6173103</td><td>593022</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>3</td><td>14251</td><td>82789</td><td>0.1721</td><td>6178846</td><td>606553</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>4</td><td>13704</td><td>80020</td><td>0.1713</td><td>6180162</td><td>612719</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>5</td><td>13950</td><td>83474</td><td>0.1671</td><td>6183503</td><td>617029</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>6</td><td>13278</td><td>79649</td><td>0.1667</td><td>6181981</td><td>624423</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>7</td><td>13930</td><td>80981</td><td>0.172</td><td>6187954</td><td>628209</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>8</td><td>14009</td><td>82907</td><td>0.169</td><td>6192131</td><td>297788</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>9</td><td>13177</td><td>77957</td><td>0.169</td><td>6187541</td><td>299907</td></tr><tr><td>In Month</td><td>36</td><td>2018</td><td>10</td><td>14161</td><td>83998</td><td>0.1686</td><td>6197415</td><td
td><td>4116</td></tr><tr><td>In Month</td><td>36</td><td>2020</td><td>10</td><td>732057</td><td>4088</td></tr><tr><td>In Month</td><td>36</td><td>2020</td><td>11</td><td>733321</td><td>4074</td></tr><tr><td>In Month</td><td>36</td><td>2020</td><td>12</td><td>733155</td><td>4036</td></tr><tr><td>In Month</td><td>36</td><td>2021</td><td>1</td><td>687882</td><td>3501</td></tr><tr><td>In Month</td><td>36</td><td>2021</td><td>2</td><td>702500</td><td>3568</td></tr><tr><td>In Month</td><td>36</td><td>2021</td><td>3</td><td>718437</td><td>3651</td></tr><tr><td>In Month</td><td>36</td><td>2021</td><td>4</td><td>731270</td><td>3717</td></tr><tr><td>In Month</td><td>36</td><td>2021</td><td>5</td><td>742020</td><td>3792</td></tr><tr><td>In Month</td><td>36</td><td>2021</td><td>6</td><td>751910</td><td>3859</td></tr><tr><td>In Month</td><td>36</td><td>2021</td> ...

# %% [markdown]
# #### Unit Testing

# %% [markdown]
# Type Check

# %%
readmits = Readmits.allcause(30)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert str(type(readmits)) == "<class 'palet.Readmits.Readmits'>", 'The Paletable object is not a Readmits object.'
print('The Paletable object is a Readmits object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is a Readmits object.
# </div>

# %%
enrolleereadmits = Enrollment().having(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert str(type(enrolleereadmits)) == "<class 'palet.Enrollment.Enrollment'>", 'The Paletable object is not an Enrollment object.'
print('The Paletable object is an Enrollment object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Enrollment object.
# </div>

# %% [markdown]
# having()

# %%
having = Enrollment().having(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
a = str(having.having_constraints)
b = a[174:205]

assert b == 'sum(readmit_ind) as has_readmit', 'Enrollment counts are not representative of enrollees who were readmitted during the given time period.'
print('Enrollment counts are representative of enrollees who were readmitted during the given time period.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment counts are representative of enrollees who were readmitted during the given time period.
# </div>

# %% [markdown]
# calculate

# %%
rate = Enrollment().calculate(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = rate.fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: counter             object
# year                object
# month                int32
# readmits             int64
# admits               int64
# readmit_rate       float64
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert 'readmits' and 'admits' and 'readmit_rate' in df.columns, 'Calculated readmit columns are not present in DataFrame'
print('Calculated readmit columns are present in DataFrame')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Calculated readmit columns are present in DataFrame
# </div>

# %% [markdown]
# Time Units

# %%
api = Enrollment(period='year').having(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert api.timeunit == 'year', 'Enrollment object and Readmits sub-object are not being counted by the proper time unit.'
print('Enrollment object and Readmits sub-object are being counted by the proper time unit.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object and Readmits sub-object are being counted by the proper time unit.
# </div>

# %%
api = Enrollment(period='month').having(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert api.timeunit == 'month', 'Enrollment object and Readmits sub-object are not being counted by the proper time unit.'
print('Enrollment object and Readmits sub-object are being counted by the proper time unit.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object and Readmits sub-object are being counted by the proper time unit.
# </div>

# %%
api = Enrollment(period='full').calculate(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert api.timeunit == 'full', 'Enrollment object and Readmits sub-object are not being counted by the proper time unit.'
print('Enrollment object and Readmits sub-object are being counted by the proper time unit.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object and Readmits sub-object are being counted by the proper time unit.
# </div>

# %%
api = Enrollment(period='partial').calculate(Readmits.allcause(30))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert api.timeunit == 'partial', 'Enrollment object and Readmits sub-object are not being counted by the proper time unit.'
print('Enrollment object and Readmits sub-object are being counted by the proper time unit.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Enrollment object and Readmits sub-object are being counted by the proper time unit.
# </div>

# %% [markdown]
# by groups - having()

# %%
having = Enrollment(period='year').byState(['CA']).having(Readmits.allcause(30))

df = having.fetch()
display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 18:17:18,486 - palet_log - INFO - adding byState to the by Group
# 2022-05-31 18:17:18,486 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:300: UserWarning: createDataFrame attempted Arrow optimization because &#39;spark.sql.execution.arrow.pyspark.enabled&#39; is set to true; however, failed by the reason below:
#   Cannot specify a mask or a size when passing an object that is converted with the __arrow_array__ protocol.
# Attempting non-optimization as &#39;spark.sql.execution.arrow.pyspark.fallback.enabled&#39; is set to true.
#   warnings.warn(msg)
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>year</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th><th>STNAME</th><th>STABBREV</th></tr></thead><tbody><tr><td>In Year</td><td>06</td><td>2018</td><td>1292876</td><td>6019</td><td>NaN</td><td>NaN</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2019</td><td>1187915</td><td>6265</td><td>-0.081</td><td>0.041</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2020</td><td>1147062</td><td>5301</td><td>-0.034</td><td>-0.154</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2021</td><td>1101318</td><td>3835</td><td>-0.04</td><td>-0.277</td><td>California</td><td>CA</td></tr><tr><td>In Year</td><td>06</td><td>2022</td><td>39747</td><td>161</td><td>-0.964</td><td>-0.958</td><td>California</td><td>CA</td></tr></tbody></table></div>

# %%
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'year': 'object',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','year','mdcd_enrollment','chip_enrollment','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = having.byMonth().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 18:20:41,425 - palet_log - INFO - adding byMonth to the by Group
# Out[30]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = having.byGender().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 18:23:57,267 - palet_log - INFO - adding byGender to by Group
# 2022-05-31 18:23:57,268 - palet_log - INFO - Adding By Group gndr_cd
# Out[33]: counter             object
# SUBMTG_STATE_CD     string
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'gndr_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','gndr_cd','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: counter             object
# SUBMTG_STATE_CD     string
# gndr_cd             string
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = having.byCoverageType().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 18:25:30,862 - palet_log - INFO - adding CoverageType to the by Group
# Out[36]: counter                 object
# SUBMTG_STATE_CD         string
# gndr_cd                 string
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# STNAME                  object
# STABBREV                object
# coverage_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'gndr_cd': 'string',
  'coverage_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object',
  'coverage_type_label':'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','gndr_cd','coverage_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV','coverage_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: counter                 object
# SUBMTG_STATE_CD         string
# gndr_cd                 string
# coverage_type           object
# year                    object
# month                    int32
# mdcd_enrollment          int64
# chip_enrollment          int64
# mdcd_pct_mom           float64
# chip_pct_mom           float64
# mdcd_pct_yoy           float64
# chip_pct_yoy           float64
# STNAME                  object
# STABBREV                object
# coverage_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# by groups - calculate()

# %%
rate = Enrollment().byYear([2020]).byState(['WA']).calculate(Readmits.allcause(30))

rate.timeunit = 'month'

df = rate.fetch()
display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 18:27:35,257 - palet_log - INFO - adding byYear to the by Group
# 2022-05-31 18:27:39,630 - palet_log - INFO - adding byState to the by Group
# 2022-05-31 18:27:39,630 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>SUBMTG_STATE_CD</th><th>year</th><th>month</th><th>readmits</th><th>admits</th><th>readmit_rate</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th><th>STNAME</th><th>STABBREV</th></tr></thead><tbody><tr><td>In Month</td><td>53</td><td>2020</td><td>1</td><td>2553</td><td>17095</td><td>0.1493</td><td>1746773</td><td>73728</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td

  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','year','month','readmits','admits','readmit_rate','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: counter             object
# SUBMTG_STATE_CD     string
# year                object
# month                int32
# readmits             int64
# admits               int64
# readmit_rate       float64
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = rate.byEthnicity().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 18:27:58,516 - palet_log - INFO - adding byEthnicity to by Group
# 2022-05-31 18:27:58,516 - palet_log - INFO - Adding By Group ethncty_cd
# calling build race ethnicity
# Out[43]: counter             object
# SUBMTG_STATE_CD     string
# ethncty_cd          string
# year                object
# month                int32
# readmits             int64
# admits               int64
# readmit_rate       float64
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# ethnicity           object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'ethncty_cd': 'string',
  'year': 'object',
  'month': 'int32',
  'readmits': 'int64',
  'admits': 'int64',
  'readmit_rate': 'float64',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object',
  'ethnicity':'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','ethncty_cd','year','month','readmits','admits','readmit_rate','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV','ethnicity'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: counter             object
# SUBMTG_STATE_CD     string
# ethncty_cd          string
# year                object
# month                int32
# readmits             int64
# admits               int64
# readmit_rate       float64
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# STNAME              object
# STABBREV            object
# ethnicity           object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = rate.byEligibilityType().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-05-31 18:28:16,611 - palet_log - INFO - adding EligibilityType to the by Group
# calling build race ethnicity
# Out[46]: counter                  object
# SUBMTG_STATE_CD          string
# ethncty_cd               string
# eligibility_type         object
# year                     object
# month                     int32
# readmits                float64
# admits                  float64
# readmit_rate            float64
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# ethnicity                object
# eligibility_category     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'SUBMTG_STATE_CD': 'string',
  'ethncty_cd': 'string',
  'eligibility_type': 'object',
  'year': 'object',
  'month': 'int32',
  'readmits': 'float64',
  'admits': 'float64',
  'readmit_rate': 'float64',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object',
  'ethnicity':'object',
  'eligibility_category': 'object'
}
ser = pd.Series(data=d, index=['counter','SUBMTG_STATE_CD','ethncty_cd','eligibility_type','year','month','readmits','admits','readmit_rate','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV','ethnicity','eligibility_category'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: counter                  object
# SUBMTG_STATE_CD          string
# ethncty_cd               string
# eligibility_type         object
# year                     object
# month                     int32
# readmits                float64
# admits                  float64
# readmit_rate            float64
# mdcd_enrollment           int64
# chip_enrollment           int64
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# ethnicity                object
# eligibility_category     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
