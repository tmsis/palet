# %% [markdown]
# #### Cluster Test File
#
# Use Case: Run this file once a new version of PALET has been pushed to their respective cluster on either the PROD or VAL Servers
#
# Purpose: Does not return dataframes, this file is used to confirm that our assertations about the PALET library are correct.
#
# Functionality Testing:
# 1. Paletable objects i.e. Enrollment, Eligibility, etc.
# 2. Counts for enrollment
# 3. By groups i.e. byMonth(), byState(), etc.
# 4. Time units  i.e. month, year, full month, partial month
# 5. Filtering by Chronic Conidition

# %%
# only required for std cluster, if testing dedicated PALET clusters do not run this cell
import sys
sys.path.append('/dbfs/FileStore/shared_uploads/akira/lib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from palet.Enrollment import Enrollment
from palet.Eligibility import Eligibility
import pandas as pd
from palet.Diagnoses import Diagnoses
from palet.ServiceCategory import ServiceCategory
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Paletable Objects

# %%
enrollapi = Enrollment()

assert str(type(enrollapi)) == "<class 'palet.Enrollment.Enrollment'>", 'The Paletable object is not an Enrollment object.'
print('The Paletable object is an Enrollment object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Enrollment object.
# </div>

# %%
eligapi = Eligibility()

assert str(type(eligapi)) == "<class 'palet.Eligibility.Eligibility'>", 'The Paletable object is not an Eligibility object.'
print('The Paletable object is an Eligibility object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Eligibility object.
# </div>

# %% [markdown]
# #### Enrollment Counts
# Work in progress

# %% [markdown]
# Yearly Counts

# %%
api = Enrollment().byYear()

df = api.fetch()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 16:47:53,843 - palet_log - INFO - adding byYear to the by Group
# </div>

# %%
df = df[['mdcd_enrollment','chip_enrollment']]

df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mdcd_enrollment</th>
#       <th>chip_enrollment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>37533400</td>
#       <td>1680784</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>87618078</td>
#       <td>3162475</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>94942910</td>
#       <td>3789852</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>95748823</td>
#       <td>4259367</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>94605172</td>
#       <td>4556629</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>93217105</td>
#       <td>4363985</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>93339719</td>
#       <td>3974170</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>97208839</td>
#       <td>3510349</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
year = {'mdcd_enrollment':[37533400,87618078,94942910,95748823,94605172,93217105,93339719,97208839],'chip_enrollment':[1680784,3162475,3789852,4259367,4556629,4363985,3974170,3510349]}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert all((df == pd.DataFrame(year))), 'Yearly counts for Medicaid enrollment do not match the expected counts.'
print('Yearly counts for Medicaid enrollment match the expected counts.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Yearly counts for Medicaid enrollment match the expected counts.
# </div>

# %% [markdown]
# #### By Groups - Filters

# %% [markdown]
# Enrollment object with by groups

# %%
df = enrollapi.byMonth().fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 16:49:15,956 - palet_log - INFO - adding byMonth to the by Group
# Out[9]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64'
}
ser = pd.Series(data=d, index=['counter','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: counter             object
# year                object
# month                int32
# mdcd_enrollment      int64
# chip_enrollment      int64
# mdcd_pct_mom       float64
# chip_pct_mom       float64
# mdcd_pct_yoy       float64
# chip_pct_yoy       float64
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = enrollapi.byRaceEthnicity().fetch()

df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 16:50:34,678 - palet_log - INFO - adding byRaceEthnicity to by Group
# 2022-04-11 16:50:34,678 - palet_log - INFO - Adding By Group race_ethncty_flag
# Out[12]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_flag': 'string',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'race': 'object',
}
ser = pd.Series(data=d, index=['counter','race_ethncty_flag','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','race'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: counter               object
# race_ethncty_flag     string
# year                  object
# month                  int32
# mdcd_enrollment        int64
# chip_enrollment        int64
# mdcd_pct_mom         float64
# chip_pct_mom         float64
# mdcd_pct_yoy         float64
# chip_pct_yoy         float64
# race                  object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = enrollapi.byEnrollmentType().fetch()
             
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 16:51:43,837 - palet_log - INFO - adding byEnrollmentType to the by Group
# Out[15]: counter                   object
# race_ethncty_flag         string
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# race                      object
# enrollment_type_label     object
# dtype: object</div>

# %%
d = {
  'counter': 'object',
  'race_ethncty_flag': 'string',
  'enrollment_type': 'object',
  'year': 'object',
  'month': 'int32',
  'mdcd_enrollment': 'int64',
  'chip_enrollment': 'int64',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'race': 'object',
  'enrollment_type_label': 'object'
}
ser = pd.Series(data=d, index=['counter','race_ethncty_flag','enrollment_type','year','month','mdcd_enrollment','chip_enrollment','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','race','enrollment_type_label'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: counter                   object
# race_ethncty_flag         string
# enrollment_type           object
# year                      object
# month                      int32
# mdcd_enrollment            int64
# chip_enrollment            int64
# mdcd_pct_mom             float64
# chip_pct_mom             float64
# mdcd_pct_yoy             float64
# chip_pct_yoy             float64
# race                      object
# enrollment_type_label     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# ## Eligibility object with by groups

# %%
df = eligapi.byState().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 17:01:33,171 - palet_log - INFO - adding byState to the by Group
# 2022-04-11 17:01:33,171 - palet_log - INFO - Adding By Group SUBMTG_STATE_CD
# Out[18]: SUBMTG_STATE_CD          string
# da_run_id                 int32
# de_fil_dt                object
# month                     int32
# elgblty_grp_cd           object
# benes                     int64
# mdcd_enrlmt               int64
# chip_enrlmt               int64
# year                     object
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# eligibility_category     object
# dtype: object</div>

# %%
print(eligapi.sql())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#                 select
#                     aa.SUBMTG_STATE_CD
# 			   ,
#                     aa.da_run_id,
#                     aa.de_fil_dt,
#                     aa.month,
#                     aa.elgblty_grp_cd,
#                     sum(aa.benes) as benes,
#                     sum(aa.mdcd_enrlmt) as mdcd_enrlmt,
#                     sum(aa.chip_enrlmt) as chip_enrlmt
#                 from
#                     palet_mart.pivoted_eligibility as aa
#                 where
#                     aa.da_run_id in ( 6280,6460,6461,6636,6637,6872,7072,7160 )
#                 group by
#                     aa.SUBMTG_STATE_CD
# 			   ,
#                     aa.da_run_id,
#                     aa.de_fil_dt,
#                     aa.month,
#                     aa.elgblty_grp_cd
#                 order by
#                     aa.SUBMTG_STATE_CD
# 			   ,
#                     aa.de_fil_dt,
#                     aa.month,
#                     aa.elgblty_grp_cd
#
# </div>

# %%
d = {
  'SUBMTG_STATE_CD': 'string',
  'da_run_id': 'int32',
  'de_fil_dt': 'object',
  'month': 'int32',
  'elgblty_grp_cd': 'object',
  'benes': 'int64',
  'mdcd_enrlmt': 'int64',
  'chip_enrlmt': 'int64',
  'year': 'object',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object',
  'eligibility_category': 'object'
}
ser = pd.Series(data=d, index=['SUBMTG_STATE_CD','da_run_id','de_fil_dt','month','elgblty_grp_cd','benes','mdcd_enrlmt','chip_enrlmt','year', 
                               'mdcd_pct_mom', 'chip_pct_mom', 'mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV','eligibility_category'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: SUBMTG_STATE_CD          string
# da_run_id                 int32
# de_fil_dt                object
# month                     int32
# elgblty_grp_cd           object
# benes                     int64
# mdcd_enrlmt               int64
# chip_enrlmt               int64
# year                     object
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# eligibility_category     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = eligapi.byGender().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 17:02:01,441 - palet_log - INFO - adding byGender to by Group
# 2022-04-11 17:02:01,441 - palet_log - INFO - Adding By Group gndr_cd
# Out[22]: SUBMTG_STATE_CD          string
# gndr_cd                  string
# da_run_id                 int32
# de_fil_dt                object
# month                     int32
# elgblty_grp_cd           object
# benes                     int64
# mdcd_enrlmt               int64
# chip_enrlmt               int64
# year                     object
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# eligibility_category     object
# dtype: object</div>

# %%
d = {
  'SUBMTG_STATE_CD': 'string',
  'gndr_cd': 'string',
  'da_run_id': 'int32',
  'de_fil_dt': 'object',
  'month': 'int32',
  'elgblty_grp_cd': 'object',
  'benes': 'int64',
  'mdcd_enrlmt': 'int64',
  'chip_enrlmt': 'int64',
  'year': 'object',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object',
  'eligibility_category': 'object'
}
ser = pd.Series(data=d, index=['SUBMTG_STATE_CD','gndr_cd','da_run_id','de_fil_dt','month','elgblty_grp_cd','benes','mdcd_enrlmt','chip_enrlmt','year','mdcd_pct_mom', 'chip_pct_mom', 'mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV','eligibility_category'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: SUBMTG_STATE_CD          string
# gndr_cd                  string
# da_run_id                 int32
# de_fil_dt                object
# month                     int32
# elgblty_grp_cd           object
# benes                     int64
# mdcd_enrlmt               int64
# chip_enrlmt               int64
# year                     object
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# eligibility_category     object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %%
df = eligapi.byIncomeBracket().fetch()
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 17:02:20,029 - palet_log - INFO - adding byIncomeBracket to the by Group
# 2022-04-11 17:02:20,029 - palet_log - INFO - Adding By Group incm_cd
# Out[25]: SUBMTG_STATE_CD          string
# gndr_cd                  string
# incm_cd                  string
# da_run_id                 int32
# de_fil_dt                object
# month                     int32
# elgblty_grp_cd           object
# benes                     int64
# mdcd_enrlmt               int64
# chip_enrlmt               int64
# year                     object
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# eligibility_category     object
# income                   object
# dtype: object</div>

# %%
d = {
  'SUBMTG_STATE_CD': 'string',
  'gndr_cd': 'string',
  'incm_cd': 'string',
  'da_run_id': 'int32',
  'de_fil_dt': 'object',
  'month': 'int32',
  'elgblty_grp_cd': 'object',
  'benes': 'int64',
  'mdcd_enrlmt': 'int64',
  'chip_enrlmt': 'int64',
  'year': 'object',
  'mdcd_pct_mom': 'float64',
  'chip_pct_mom': 'float64',
  'mdcd_pct_yoy': 'float64',
  'chip_pct_yoy': 'float64',
  'STNAME': 'object',
  'STABBREV': 'object',
  'eligibility_category': 'object',
  'income': 'object'
}
ser = pd.Series(data=d, index=['SUBMTG_STATE_CD','gndr_cd','incm_cd','da_run_id','de_fil_dt','month','elgblty_grp_cd','benes','mdcd_enrlmt','chip_enrlmt','year','mdcd_pct_mom','chip_pct_mom','mdcd_pct_yoy','chip_pct_yoy','STNAME','STABBREV','eligibility_category','income'])
ser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: SUBMTG_STATE_CD          string
# gndr_cd                  string
# incm_cd                  string
# da_run_id                 int32
# de_fil_dt                object
# month                     int32
# elgblty_grp_cd           object
# benes                     int64
# mdcd_enrlmt               int64
# chip_enrlmt               int64
# year                     object
# mdcd_pct_mom            float64
# chip_pct_mom            float64
# mdcd_pct_yoy            float64
# chip_pct_yoy            float64
# STNAME                   object
# STABBREV                 object
# eligibility_category     object
# income                   object
# dtype: object</div>

# %%
assert (ser == df.dtypes).all(), 'The columns or data types returned do not match the expected values.'
print('DataFrame contains the correct columns.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame contains the correct columns.
# </div>

# %% [markdown]
# #### Time Units

# %%
api = Enrollment().byMonth()

df = api.fetch()

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 17:02:53,568 - palet_log - INFO - adding byMonth to the by Group
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Month</td><td>2014</td><td>1</td><td>14975535</td><td>486478</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>2</td><td>15432733</td><td>497923</td><td>0.031</td><td>0.024</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>3</td><td>15886865</td><td>504583</td><td>0.029</td><td>0.013</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>4</td><td>17186024</td><td>571423</td><td>0.082</td><td>0.132</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>5</td><td>17367637</td><td>568343</td><td>0.011</td><td>-0.005</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>6</td><td>17534955</td><td>567161</td><td>0.01</td><td>-0.002</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>7</td><td>24315774</td><td>1066883</td><td>0.387</td><td>0.881</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>8</td><td>24629738</td><td>1044634</td><td>0.013</td><td>-0.021</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>9</td><td>24913112</td><td>1016549</td><td>0.012</td><td>-0.027</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>10</td><td>31079041</td><td>1155004</td><td>0.247</td><td>0.136</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>11</td><td>34158869</td><td>1151790</td><td>0.099</td><td>-0.003</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2014</td><td>12</td><td>34560350</td><td>1154870</td><td>0.012</td><td>0.003</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>
')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Enrollment object.
# </div>

# %%
conapi = Eligibility([6278, 6280], conapi)

assert str(type(conapi)) == "<class 'palet.Eligibility.Eligibility'>", 'The Paletable object is not an Eligibility object.'
print('The Paletable object is an Eligibility object.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The Paletable object is an Eligibility object.
# </div>

# %% [markdown]
# #### Chronic Condition
# Work in progress

# %% [markdown]
# Filtering and marking by one chronic condition

# %%
AFib = ['I230', 'I231', 'I232', 'I233', 'I234', 'I235', 'I236', 'I237', 'I238', 'I213', 'I214', 'I219', 'I220', 'I221', 'I222', 'I228', 'I229', 'I21A1', 'I21A9', 'I2101', 'I2102', 'I2109', 'I2111', 'I2119', 'I2121', 'I2129']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ccapi = Enrollment([6280]).byMonth().mark(Diagnoses.where(ServiceCategory.inpatient, AFib), 'AFib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 17:05:37,447 - palet_log - INFO - adding byMonth to the by Group
# </div>

# %%
df = ccapi.fetch()
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>AFib</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Month</td><td>2021</td><td>1</td><td>0</td><td>87572662</td><td>2853684</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>1</td><td>1</td><td>185953</td><td>29</td><td>-0.998</td><td>-1.0</td><td>-0.998</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>2</td><td>0</td><td>88066483</td><td>2842216</td><td>472.595</td><td>98006.448</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>2</td><td>1</td><td>184838</td><td>32</td><td>-0.998</td><td>-1.0</td><td>-0.998</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>3</td><td>0</td><td>88729652</td><td>2824540</td><td>479.04</td><td>88265.875</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>3</td><td>1</td><td>184298</td><td>31</td><td>-0.998</td><td>-1.0</td><td>-0.998</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>4</td><td>0</td><td>89307790</td><td>2823082</td><td>483.584</td><td>91066.161</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>4</td><td>1</td><td>183007</td><td>30</td><td>-0.998</td><td>-1.0</td><td>-0.998</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>5</td><td>0</td><td>89828588</td><td>2815974</td><td>489.848</td><td>93864.8</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>5</td><td>1</td><td>181300</td><td>30</td><td>-0.998</td><td>-1.0</td><td>-0.998</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>6</td><td>0</td><td>90377487</td><td>2806963</td><td>497.497</td><td>93564.433</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>6</td><td>1</td><td>179329</td><td>28</td><td>-0.998</td><td>-1.0</td><td>-0.998</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>7</td><td>0</td><td>90926593</td><td>2798739</td><td>506.038</td><td>99953.964</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>7</td><td>1</td><td>177483</td><td>27</td><td>-0.998</td><td>-1.0</td><td>-0.998</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>8</td><td>0</td><td>91544083</td><td>2791966</td><td>514.791</td><td>103405.148</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>
E1059','E10610','E10618','E10620','E10621','E10622','E10628','E10630','E10638','E10641','E10649','E1065','E1069','E108','E109','E1100','E1101','E1110','E1111','E1121','E1122','E1129','E11311','E11319','E11321','E113211','E113212','E113213','E113219','E11329','E113291','E113292','E113293','E113299','E11331','E113311','E113312','E113313','E113319','E11339','E113391','E113392','E113393','E113399','E11341','E113411','E113412','E113413','E113419','E11349','E113491','E113492','E113493','E113499','E11351','E113511','E113512','E113513','E113519','E113521','E113522','E113523','E113529','E113531','E113532','E113533','E113539','E113541','E113542','E113543','E113549','E113551','E113552','E113553','E113559','E11359','E113591','E113592','E113593','E113599','E1136','E1137X1','E1137X2','E1137X3','E1137X9','E1139','E1140','E1141','E1142','E1143','E1144','E1149','E1151','E1152','E1159','E11610','E11618','E11620','E11621','E11622','E11628','E11630','E11638','E11641','E11649','E1165','E1169','E118','E119','E1300','E1301','E1310','E1311','E1321','E1322','E1329','E13311','E13319','E13321','E133211','E133212','E133213','E133219','E13329','E133291','E133292','E133293','E133299','E13331','E133311','E133312','E133313','E133319','E13339','E133391','E133392','E133393','E133399','E13341','E133411','E133412','E133413','E133419','E13349','E133491','E133492','E133493','E133499','E13351','E133511','E133512','E133513','E133519','E133521','E133522','E133523','E133529','E133531','E133532','E133533','E133539','E133541','E133542','E133543','E133549','E133551','E133552','E133553','E133559','E13359','E1336','E1339','E1340','E1341','E1342','E1343','E1344','E1349','E1351','E1352','E1359','E13610','E13618','E13620','E13621','E13622','E13628','E13630','E13638','E13641','E13649','E1365','E1369','E138','E139']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ccapi = Enrollment([6280]).byMonth()          \
  .mark(                                         \
    Diagnoses.within([                           \
      (ServiceCategory.inpatient, 1),            \
      (ServiceCategory.other_services, 2)],      \
          Diabetes), 'Diabetes')                 \
  .mark(                                         \
     Diagnoses.within([                          \
       (ServiceCategory.inpatient, 1),           \
       (ServiceCategory.other_services, 2)],     \
           AFib), 'AFib')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-04-11 17:06:06,934 - palet_log - INFO - adding byMonth to the by Group
# </div>

# %%
df = ccapi.fetch()
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>counter</th><th>year</th><th>month</th><th>Diabetes</th><th>AFib</th><th>mdcd_enrollment</th><th>chip_enrollment</th><th>mdcd_pct_mom</th><th>chip_pct_mom</th><th>mdcd_pct_yoy</th><th>chip_pct_yoy</th></tr></thead><tbody><tr><td>In Month</td><td>2021</td><td>1</td><td>0</td><td>0</td><td>86632910</td><td>2851703</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>2021</td><td>1</td><td>0</td><td>1</td><td>109130</td><td>26</td><td>-0.999</td><td>-1.0</td><td>-0.999</td><td>-1.0</td></tr><tr><td>In Month</td><td>2021</td><td>1</td><td>1</td><td>0</td><td>939752</td><td>1981</td><td>7.611</td><td>75.192</td><td>7.611</td><td>75.192</td></tr><tr><td>In Month</td><td>2021</td><td>1</td><td>1</td><td>1</td><td>76823</td><td>3</td><td>-0.918</td><td>-0.998</td><td>-0.918</td><td>-0.998</td></tr><tr><td>In Month</td><td>2021</td><td>2</td><td>0</td><td>0</td><td>87124677</td><td>2840215</td><td>1133.096</td><td>946737.333</td><td>null</td><td>null</td></tr><tr><td>In Month</td><td>